# %% [markdown]
# ## Data Science Bootcamp | Projekt końcowy | Wycena nieruchomości | Projekt Machine Learning

# %% [markdown]
# **Projekt zrealizowany w oparciu o zbioru danych "Ames Iowa: Alternative to the Boston Housing Data Set"**
#
# Michał Owczarek XII.2020
# ***

# %% [markdown]
# ### Zawartość | Spis Treści
#
# 1. Wprowadzenie
# 2. Przygotowanie danych
# 3. Czyszczenie danych
# 4. Eksporacyjna analiza danych
# 5. Metody modelowania
#     * Regresja Liniowa
#     * Elastic Net
#     * Regresja Ridge
#     * Regresia Lasso
#     * Random Forest
#     * Gradient Boosting
# 6. Podsumowanie wyników i wnioski
#
# ***

# %% [markdown]
# ## **1. Wprowadzenie**
#
# W ramach tego notebooka przygotowany został całościowy projekt końcowy realizowany w ramach Data Science Bootcamp. Projekt zrealizowany jest w oparciu o zbiór danych: "Ames Iowa: Alternative to the Boston Housing Data Set"
#
# ***Główne cele projketu***
# - przeprowadzenie kompletnej analizy danych uwzgledniając przygotowanie danych, czyszczenie danych, eksplorację danych
# - zastosowanie różnych technik modelowania uwzględniając porównanie i interpretację wyników
#
# ***

# %% [markdown]
# ## **2. Przygotowanie danych**
#
# Link do danych:
# <br> http://web.stanford.edu/class/stats191/data/ames2000_NAfix.csv
# <br>Dokładny opis danych:
# <br>http://web.stanford.edu/class/stats191/data/amesdoc.txt

# %%
# import bibliotek 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Import danych**

# %%
url = "http://web.stanford.edu/class/stats191/data/ames2000_NAfix.csv" # ścieżka do pliku z Chrome DevTools Console
data_orginal = pd.read_csv(url)

# dane, które będe modyfikował zapisuje skopiowanym data frame 
data = data_orginal.copy()

# %% [markdown]
# ### **Rozpoznanie data setu**
#
# * Wczytuję pierwsze i ostatnie 5 kolumn

# %%
# sprawdzam pierwsze 5 wierszy data setu
data.head(5)
# Out:
#    MS.SubClass MS.Zoning Lot.Frontage  Lot.Area Street Alley Lot.Shape  \
# 0          120        RL           34      3901   Pave  None       Reg
# 1           20        RL           70      8400   Pave  None       Reg
# 2           85        RL           60      7200   Pave  None       Reg
# 3           90        RL           64      7018   Pave  None       Reg
# 4           60        RL          111     16259   Pave  None       Reg
#
#   Land.Contour Utilities Lot.Config  ... Pool.Area Pool.QC  Fence  \
# 0          Lvl    AllPub     Inside  ...         0    None   None
# 1          Lvl    AllPub     Corner  ...         0    None  MnPrv
# 2          Lvl    AllPub     Inside  ...         0    None  MnPrv
# 3          Bnk    AllPub     Inside  ...         0    None   None
# 4          Lvl    AllPub     Corner  ...         0    None   None
#
#   Misc.Feature Misc.Val Mo.Sold  Yr.Sold  Sale.Type  Sale.Condition  SalePrice
# 0         None        0       8     2007        New         Partial     204000
# 1         None        0       4     2010        WD           Normal     126000
# 2         None        0       4     2009        WD           Normal     133900
# 3         None        0       6     2009        WD           Alloca     118858
# 4         None        0       9     2006        New         Partial     342643
#
# [5 rows x 80 columns]

# %%
#sprawdzam ostatnie 5 wierszy data setu
data.tail(5)
# Out:
#       MS.SubClass MS.Zoning Lot.Frontage  Lot.Area Street Alley Lot.Shape  \
# 1995           80        RL           80      8000   Pave  None       Reg
# 1996          180        RM           35      3675   Pave  None       Reg
# 1997           60        RL           76     10142   Pave  None       IR1
# 1998           85        RL         None      7252   Pave  None       IR1
# 1999          160        FV           34      2998   Pave  None       Reg
#
#      Land.Contour Utilities Lot.Config  ... Pool.Area Pool.QC Fence  \
# 1995          Lvl    AllPub     Inside  ...         0    None  GdWo
# 1996          Lvl    AllPub     Inside  ...         0    None  None
# 1997          Lvl    AllPub     Inside  ...         0    None  None
# 1998          Lvl    AllPub    CulDSac  ...         0    None  None
# 1999          Lvl    AllPub     Inside  ...         0    None  None
#
#      Misc.Feature Misc.Val Mo.Sold  Yr.Sold  Sale.Type  Sale.Condition  \
# 1995         None        0       7     2009        WD           Normal
# 1996         None        0       6     2008        WD           Normal
# 1997         None        0       1     2010        WD           Normal
# 1998         None        0       4     2009        WD           Normal
# 1999         None        0       8     2009        WD           Normal
#
#       SalePrice
# 1995     138000
# 1996     148000
# 1997     233000
# 1998     134900
# 1999     180000
#
# [5 rows x 80 columns]

# %%
data.shape
#2000 obserwacji dla 80 zmiennych
# Out:
# (2000, 80)

# %% [markdown]
# * Sprawdzam jakie wartości przyjmują zmienne dla nieruchomości o największej i najniższej cenie sprzedaży.

# %%
pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', -1)

#sprawdzam cały wiersz dla którego cena jest najwyższa

data[data.SalePrice == data.SalePrice.max()]
# Out:
# /Users/m.owczarek/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   This is separate from the ipykernel package so we can avoid doing imports until
#      MS.SubClass MS.Zoning Lot.Frontage  Lot.Area Street Alley Lot.Shape Land.Contour Utilities Lot.Config Land.Slope Neighborhood Condition.1 Condition.2 Bldg.Type House.Style  Overall.Qual  Overall.Cond  Year.Built  Year.Remod.Add Roof.Style Roof.Matl Exterior.1st Exterior.2nd Mas.Vnr.Type Mas.Vnr.Area Exter.Qual Exter.Cond Foundation Bsmt.Qual Bsmt.Cond Bsmt.Exposure BsmtFin.Type.1 BsmtFin.SF.1 BsmtFin.Type.2 BsmtFin.SF.2 Bsmt.Unf.SF Total.Bsmt.SF Heating Heating.QC Central.Air Electrical  X1st.Flr.SF  X2nd.Flr.SF  Low.Qual.Fin.SF  Gr.Liv.Area Bsmt.Full.Bath Bsmt.Half.Bath  Full.Bath  Half.Bath  Bedroom.AbvGr  Kitchen.AbvGr Kitchen.Qual  TotRms.AbvGrd Functional  Fireplaces Fireplace.Qu Garage.Type Garage.Yr.Blt Garage.Finish Garage.Cars Garage.Area Garage.Qual Garage.Cond Paved.Drive  Wood.Deck.SF  Open.Porch.SF  Enclosed.Porch  X3Ssn.Porch  Screen.Porch  Pool.Area Pool.QC Fence Misc.Feature  Misc.Val  Mo.Sold  Yr.Sold Sale.Type Sale.Condition  SalePrice
# 580  60           RL        104          21535     Pave   None  IR1       Lvl          AllPub    Corner     Gtl        NoRidge      Norm        Norm        1Fam      2Story      10            6             1994        1995            Gable      WdShngl   HdBoard      HdBoard      BrkFace      1170         Ex         TA         PConc      Ex        TA        Gd            GLQ            1455         Unf            0            989         2444          GasA    Ex         Y           SBrkr      2444         1872         0                4316         0              1              3          1          4              1              Ex           10             Typ        2           Ex           Attchd      1994          Fin           3           832         TA          TA          Y           382           50             0               0            0             0          None    None  None         0         1        2007     WD        Normal         755000

# %%
#sprawdzam cały wiersz dla którego cena jest najniższa

data[data.SalePrice == data.SalePrice.min()]
# Out:
#       MS.SubClass MS.Zoning Lot.Frontage  Lot.Area Street Alley Lot.Shape Land.Contour Utilities Lot.Config Land.Slope Neighborhood Condition.1 Condition.2 Bldg.Type House.Style  Overall.Qual  Overall.Cond  Year.Built  Year.Remod.Add Roof.Style Roof.Matl Exterior.1st Exterior.2nd Mas.Vnr.Type Mas.Vnr.Area Exter.Qual Exter.Cond Foundation Bsmt.Qual Bsmt.Cond Bsmt.Exposure BsmtFin.Type.1 BsmtFin.SF.1 BsmtFin.Type.2 BsmtFin.SF.2 Bsmt.Unf.SF Total.Bsmt.SF Heating Heating.QC Central.Air Electrical  X1st.Flr.SF  X2nd.Flr.SF  Low.Qual.Fin.SF  Gr.Liv.Area Bsmt.Full.Bath Bsmt.Half.Bath  Full.Bath  Half.Bath  Bedroom.AbvGr  Kitchen.AbvGr Kitchen.Qual  TotRms.AbvGrd Functional  Fireplaces Fireplace.Qu Garage.Type Garage.Yr.Blt Garage.Finish Garage.Cars Garage.Area Garage.Qual Garage.Cond Paved.Drive  Wood.Deck.SF  Open.Porch.SF  Enclosed.Porch  X3Ssn.Porch  Screen.Porch  Pool.Area Pool.QC Fence Misc.Feature  Misc.Val  Mo.Sold  Yr.Sold Sale.Type Sale.Condition  SalePrice
# 1253  30           RM        68           9656      Pave   None  Reg       Lvl          AllPub    Inside     Gtl        OldTown      Norm        Norm        1Fam      1Story      2             2             1923        1970            Gable      CompShg   AsbShng      AsbShng      None         0            TA         Fa         BrkTil     Fa        Fa        No            Unf            0            Unf            0            678         678           GasA    TA         N           SBrkr      832          0            0                832          0              0              1          0          2              1              TA           5              Typ        1           Gd           Detchd      1928          Unf           2           780         Fa          Fa          N           0             0              0               0            0             0          None    None  None         0         6        2010     WD        Abnorml        12789

# %% [markdown]
# * Sprawdzam jakie wartości przyjmują poszczególne zmienne

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(data.dtypes)
# Out:
# MS.SubClass        int64
# MS.Zoning          object
# Lot.Frontage       object
# Lot.Area           int64
# Street             object
# Alley              object
# Lot.Shape          object
# Land.Contour       object
# Utilities          object
# Lot.Config         object
# Land.Slope         object
# Neighborhood       object
# Condition.1        object
# Condition.2        object
# Bldg.Type          object
# House.Style        object
# Overall.Qual       int64
# Overall.Cond       int64
# Year.Built         int64
# Year.Remod.Add     int64
# Roof.Style         object
# Roof.Matl          object
# Exterior.1st       object
# Exterior.2nd       object
# Mas.Vnr.Type       object
# Mas.Vnr.Area       object
# Exter.Qual         object
# Exter.Cond         object
# Foundation         object
# Bsmt.Qual          object
# Bsmt.Cond          object
# Bsmt.Exposure      object
# BsmtFin.Type.1     object
# BsmtFin.SF.1       object
# BsmtFin.Type.2     object
# BsmtFin.SF.2       object
# Bsmt.Unf.SF        object
# Total.Bsmt.SF      object
# Heating            object
# Heating.QC         object
# Central.Air        object
# Electrical         object
# X1st.Flr.SF        int64
# X2nd.Flr.SF        int64
# Low.Qual.Fin.SF    int64
# Gr.Liv.Area        int64
# Bsmt.Full.Bath     object
# Bsmt.Half.Bath     object
# Full.Bath          int64
# Half.Bath          int64
# Bedroom.AbvGr      int64
# Kitchen.AbvGr      int64
# Kitchen.Qual       object
# TotRms.AbvGrd      int64
# Functional         object
# Fireplaces         int64
# Fireplace.Qu       object
# Garage.Type        object
# Garage.Yr.Blt      object
# Garage.Finish      object
# Garage.Cars        object
# Garage.Area        object
# Garage.Qual        object
# Garage.Cond        object
# Paved.Drive        object
# Wood.Deck.SF       int64
# Open.Porch.SF      int64
# Enclosed.Porch     int64
# X3Ssn.Porch        int64
# Screen.Porch       int64
# Pool.Area          int64
# Pool.QC            object
# Fence              object
# Misc.Feature       object
# Misc.Val           int64
# Mo.Sold            int64
# Yr.Sold            int64
# Sale.Type          object
# Sale.Condition     object
# SalePrice          int64
# dtype: object

# %% [markdown]
# * Sprawdzam podstawowe informacje statystyczne na temat kolumn z wartościami numerycznymi. Średnia, odchylenie standardowe, wartośc minimalna i maksymalna, mediana dla każdej kolumny

# %%
data.describe(include=[np.number], percentiles=[.5]).transpose().drop("count", axis=1)
# Out:
#                         mean           std      min       50%       max
# MS.SubClass      56.9450      42.699281     20.0     50.0      190.0
# Lot.Area         10296.6650   8828.208491   1300.0   9465.0    215245.0
# Overall.Qual     6.0820       1.387169      1.0      6.0       10.0
# Overall.Cond     5.5740       1.105502      1.0      5.0       9.0
# Year.Built       1971.0795    29.985426     1872.0   1972.0    2010.0
# Year.Remod.Add   1984.0135    20.881771     1950.0   1993.0    2010.0
# X1st.Flr.SF      1158.7155    379.701015    407.0    1088.0    4692.0
# X2nd.Flr.SF      334.3805     427.519973    0.0      0.0       2065.0
# Low.Qual.Fin.SF  4.3790       42.555738     0.0      0.0       697.0
# Gr.Liv.Area      1497.4750    498.561719    407.0    1447.5    5642.0
# Full.Bath        1.5625       0.551585      0.0      2.0       4.0
# Half.Bath        0.3730       0.501993      0.0      0.0       2.0
# Bedroom.AbvGr    2.8715       0.827847      0.0      3.0       8.0
# Kitchen.AbvGr    1.0465       0.219913      0.0      1.0       3.0
# TotRms.AbvGrd    6.4475       1.569228      3.0      6.0       14.0
# Fireplaces       0.5960       0.650381      0.0      1.0       4.0
# Wood.Deck.SF     93.0585      126.633128    0.0      0.0       870.0
# Open.Porch.SF    46.3350      65.685433     0.0      25.0      742.0
# Enclosed.Porch   23.9365      66.144388     0.0      0.0       1012.0
# X3Ssn.Porch      2.1160       20.668119     0.0      0.0       320.0
# Screen.Porch     15.6815      54.270505     0.0      0.0       480.0
# Pool.Area        2.9340       41.080828     0.0      0.0       800.0
# Misc.Val         42.5130      440.831080    0.0      0.0       15500.0
# Mo.Sold          6.2175       2.726336      1.0      6.0       12.0
# Yr.Sold          2007.7995    1.316118      2006.0   2008.0    2010.0
# SalePrice        180240.9020  78461.927874  12789.0  160000.0  755000.0

# %% [markdown]
# Na podstawie tej anlizy widzimy między innymi, że:
# - najwyższa cena za nieruchomość wynosi 755 000 USD, a najniższa cena za nieruchomość wynosi 12 789 USD, średnia cena to 180 240 USD
# - największa powierzchnia nieruchomośco wynosi 5642 sq ft, a najmiejsza powierzchnia wynosi 407 sq ft, średnia powierzchnia to 1497 sq ft
# ***

# %% [markdown]
# * Sprawdzam podstawowe informacje statystyczne dla kolumn gdzie wartości są nienumeryczne (kategoryczne)

# %%
data.describe(include=[np.object]).transpose().drop("count", axis=1)
# Out:
#                unique      top  freq
# MS.Zoning       7      RL       1549
# Lot.Frontage    121    None     334
# Street          2      Pave     1992
# Alley           3      None     1865
# Lot.Shape       4      Reg      1275
# Land.Contour    4      Lvl      1809
# Utilities       1      AllPub   2000
# Lot.Config      5      Inside   1452
# Land.Slope      3      Gtl      1900
# Neighborhood    27     Nonemes  303
# Condition.1     9      Norm     1721
# Condition.2     7      Norm     1981
# Bldg.Type       5      1Fam     1665
# House.Style     8      1Story   1010
# Roof.Style      6      Gable    1580
# Roof.Matl       7      CompShg  1967
# Exterior.1st    14     VinylSd  686
# Exterior.2nd    16     VinylSd  681
# Mas.Vnr.Type    5      None     1216
# Mas.Vnr.Area    363    0        1215
# Exter.Qual      4      TA       1230
# Exter.Cond      4      TA       1734
# Foundation      6      PConc    873
# Bsmt.Qual       6      TA       892
# Bsmt.Cond       6      TA       1783
# Bsmt.Exposure   5      No       1306
# BsmtFin.Type.1  7      GLQ      584
# BsmtFin.SF.1    817    0        617
# BsmtFin.Type.2  7      Unf      1694
# BsmtFin.SF.2    212    0        1746
# Bsmt.Unf.SF     928    0        170
# Total.Bsmt.SF   871    864      56
# Heating         6      GasA     1968
# Heating.QC      5      Ex       1012
# Central.Air     2      Y        1873
# Electrical      4      SBrkr    1837
# Bsmt.Full.Bath  5      0        1154
# Bsmt.Half.Bath  4      0        1870
# Kitchen.Qual    4      TA       1025
# Functional      7      Typ      1868
# Fireplace.Qu    6      None     980
# Garage.Type     7      Attchd   1182
# Garage.Yr.Blt   101    None     112
# Garage.Finish   4      Unf      831
# Garage.Cars     7      2        1091
# Garage.Area     531    0        110
# Garage.Qual     6      TA       1785
# Garage.Cond     6      TA       1816
# Paved.Drive     3      Y        1809
# Pool.QC         5      None     1989
# Fence           5      None     1605
# Misc.Feature    5      None     1926
# Sale.Type       10     WD       1738
# Sale.Condition  6      Normal   1640

# %% [markdown]
# Na podstawie tej anlizy widzimy:
# - ilość unikalnych wartości dla każdej zminnej (**unique**)
# - najczęściej występująca wartość (**top**)
# - częstotliwość najczęściej występującej wartości (**freq**)
# ***

# %% [markdown]
# Uwagę zwraca fakt, że w tym datasecie jest bardzo dużo zmiennych z wartościami, gdzie typ danych to `'Object'`. W kilku przypadkach zmienne przyjmują wartości liczbowe w tym także 0 (ale zapisane są jako string), a dla kilku obserwacji wartość `'None'`. Sprawdźmy dla przykładu unikalne wartości dla zmiennej: `'Mas.Vnr.Area'` oraz `'BsmtFin.SF.2'`

# %%
# Sprawdzam, czy wartość 'None' występuje w kolumnie 'Mas.Vnr.Area'
data['Mas.Vnr.Area'].isin(['None']).any()
# Out:
# True

# %%
# Sprawdzam, jakie unikalne wartości występują w kolumnie 'Mas.Vnr.Area'
data['Mas.Vnr.Area'].unique()
# Out:
# array(['182', '0', '370', '244', '123', '260', '50', '970', '630', '113',
#        '156', '299', '242', '84', '40', '85', 'None', '119', '238', '161',
#        '149', '76', '100', '272', '248', '240', '921', '650', '28', '150',
#        '60', '340', '653', '45', '89', '20', '208', '164', '116', '144',
#        '158', '305', '466', '278', '223', '584', '198', '226', '206',
#        '16', '197', '188', '1159', '360', '184', '92', '196', '262',
#        '479', '302', '309', '420', '90', '134', '1110', '216', '42',
#        '738', '502', '157', '298', '147', '285', '288', '94', '456',
#        '673', '327', '210', '306', '138', '243', '481', '296', '344',
#        '268', '30', '530', '88', '74', '112', '1290', '171', '304', '256',
#        '215', '290', '366', '280', '352', '106', '576', '320', '232',
#        '174', '253', '470', '621', '104', '252', '108', '44', '168',
#        '132', '492', '68', '504', '287', '217', '365', '500', '247',
#        '126', '568', '176', '371', '435', '70', '140', '877', '187',
#        '328', '430', '114', '387', '75', '450', '246', '186', '442',
#        '270', '265', '318', '506', '356', '200', '120', '424', '203',
#        '95', '362', '170', '65', '154', '275', '202', '549', '66', '473',
#        '218', '166', '146', '229', '162', '603', '180', '80', '130',
#        '128', '204', '1170', '734', '250', '491', '342', '235', '1095',
#        '137', '101', '337', '495', '178', '513', '110', '436', '220',
#        '472', '554', '237', '72', '571', '451', '348', '300', '212', '57',
#        '36', '353', '870', '391', '289', '754', '1224', '515', '886',
#        '105', '46', '142', '165', '657', '91', '54', '423', '726', '145',
#        '860', '51', '350', '183', '310', '396', '428', '67', '385', '23',
#        '194', '293', '660', '121', '284', '192', '772', '425', '143',
#        '276', '975', '96', '24', '459', '227', '664', '153', '136', '501',
#        '189', '125', '82', '528', '230', '412', '1047', '52', '99', '333',
#        '579', '372', '264', '34', '422', '359', '323', '652', '56', '251',
#        '222', '160', '281', '172', '364', '432', '53', '32', '480', '14',
#        '122', '69', '38', '600', '261', '127', '796', '283', '336', '368',
#        '135', '286', '234', '426', '440', '47', '98', '239', '509', '816',
#        '225', '87', '245', '148', '259', '169', '383', '351', '768',
#        '405', '335', '102', '410', '18', '766', '312', '297', '402',
#        '254', '632', '380', '382', '388', '97', '572', '205', '415', '58',
#        '292', '1600', '651', '397', '724', '1115', '64', '468', '355',
#        '894', '163', '748', '1', '86', '550', '615', '714', '532', '525',
#        '109', '1129', '448', '266', '190', '408', '258', '236', '291',
#        '41', '640', '228', '400', '219', '668', '378', '526', '510',
#        '117', '1050', '634', '945'], dtype=object)

# %%
# Sprawdzam, czy wartość 'None' występuje w kolumnie 'BsmtFin.SF.2'
data['BsmtFin.SF.2'].isin(['None']).any()
# Out:
# True

# %%
# Sprawdzam, jakie unikalne wartości występują w kolumnie 'BsmtFin.SF.2'
data['BsmtFin.SF.2'].unique()
# Out:
# array(['0', '78', '915', '764', '400', '252', '219', '163', '184', '755',
#        '281', '215', '539', '76', '117', '350', '841', '167', '630',
#        '670', '165', '180', '1083', '590', '147', '411', '469', '500',
#        '799', '884', '105', '42', '270', '202', '904', '532', '850',
#        '128', '1393', '544', '46', '750', '972', '127', '391', '176',
#        '466', '1127', '273', '580', '393', '512', '175', '156', '351',
#        '694', '791', '193', '334', '1080', '852', '375', '869', '761',
#        '110', '239', '64', '144', '121', '627', '688', '264', '68', '321',
#        '486', '374', '276', '859', '360', '201', '337', '123', '435',
#        '661', '263', 'None', '842', '262', '93', '81', '159', '382',
#        '606', '530', '555', '596', '604', '479', '600', '622', '1020',
#        '497', '196', '396', '72', '52', '153', '723', '1164', '41', '891',
#        '168', '472', '232', '278', '308', '286', '492', '240', '465',
#        '28', '811', '529', '288', '173', '364', '820', '294', '875',
#        '139', '116', '450', '483', '955', '499', '547', '344', '284',
#        '306', '1061', '495', '712', '506', '32', '1474', '474', '608',
#        '679', '722', '829', '297', '748', '531', '468', '620', '216',
#        '60', '154', '120', '162', '438', '682', '526', '826', '449',
#        '448', '551', '336', '491', '419', '456', '290', '258', '40',
#        '522', '182', '63', '210', '12', '247', '96', '380', '243', '119',
#        '149', '354', '108', '692', '319', '80', '345', '612', '1029',
#        '106', '1063', '1039', '831', '480', '174', '668', '66', '442',
#        '250', '150', '873', '377', '311', '1037', '613', '645', '1526',
#        '95'], dtype=object)

# %% [markdown]
# Jak widać dla tych zmiennych obserwacje przyjmują wartości liczbowe (zapisane jako string) i wartość `'None'`.
#
# Taka sytuacja dotyczy zmiennych:
#
# `'Lot.Frontage'`, `'Mas.Vnr.Area'`, `'BsmtFin.SF.1'`,`'BsmtFin.SF.2'`,`'Bsmt.Unf.SF'`, `'Total.Bsmt.SF'`, `'Bsmt.Full.Bath'`, `'Bsmt.Half.Bath'`, `'Garage.Yr.Blt'`, `'Garage.Cars'`, `'Garage.Area'`
#
#
# Na etapie czyszczenia danych zajmę się zamienienim wartości `'None'` na 0 jako `'String'`, a później zamienię je na `'Integer'` - wartości liczbowe.
# W przypadku zmiennej `'Garage.Yr.Blt'` dokonam dodatkowego przekształcenia, w pierwszej kolejności wyliczę wiek garażu, który zapiszę w nowej kolumnie.

# %% [markdown]
# ## **3. Czyszczenie danych**

# %% [markdown]
# W tej części zajmę się czyszczeniem danych. Jednak przed modyfikacjami danych skopiuję data frame `'data'`.

# %%
data_updated = data.copy()
data_updated.head(3)
# Out:
#    MS.SubClass MS.Zoning Lot.Frontage  Lot.Area Street Alley Lot.Shape Land.Contour Utilities Lot.Config Land.Slope Neighborhood Condition.1 Condition.2 Bldg.Type House.Style  Overall.Qual  Overall.Cond  Year.Built  Year.Remod.Add Roof.Style Roof.Matl Exterior.1st Exterior.2nd Mas.Vnr.Type Mas.Vnr.Area Exter.Qual Exter.Cond Foundation Bsmt.Qual Bsmt.Cond Bsmt.Exposure BsmtFin.Type.1 BsmtFin.SF.1 BsmtFin.Type.2 BsmtFin.SF.2 Bsmt.Unf.SF Total.Bsmt.SF Heating Heating.QC Central.Air Electrical  X1st.Flr.SF  X2nd.Flr.SF  Low.Qual.Fin.SF  Gr.Liv.Area Bsmt.Full.Bath Bsmt.Half.Bath  Full.Bath  Half.Bath  Bedroom.AbvGr  Kitchen.AbvGr Kitchen.Qual  TotRms.AbvGrd Functional  Fireplaces Fireplace.Qu Garage.Type Garage.Yr.Blt Garage.Finish Garage.Cars Garage.Area Garage.Qual Garage.Cond Paved.Drive  Wood.Deck.SF  Open.Porch.SF  Enclosed.Porch  X3Ssn.Porch  Screen.Porch  Pool.Area Pool.QC  Fence Misc.Feature  Misc.Val  Mo.Sold  Yr.Sold Sale.Type Sale.Condition  SalePrice
# 0  120          RL        34           3901      Pave   None  Reg       Lvl          AllPub    Inside     Gtl        NridgHt      Norm        Norm        Twnhs     1Story      6             5             2005        2006            Gable      CompShg   VinylSd      VinylSd      Stone        182          Gd         TA         PConc      Gd        TA        Av            ALQ            866          Unf            0            436         1302          GasA    Ex         Y           SBrkr      1302         0            0                1302         1              0              1          1          1              1              Gd           5              Typ        1           Gd           Attchd      2005          RFn           2           631         TA          TA          Y           110           50             0               0            0             0          None    None   None         0         8        2007     New       Partial        204000
# 1  20           RL        70           8400      Pave   None  Reg       Lvl          AllPub    Corner     Gtl        Nonemes      Norm        Norm        1Fam      1Story      4             5             1970        1970            Gable      CompShg   Plywood      Plywood      None         0            TA         TA         CBlock     TA        TA        No            ALQ            804          Rec            78           0           882           GasA    TA         Y           SBrkr      882          0            0                882          1              0              1          0          2              1              TA           4              Typ        0           None         Attchd      1970          Fin           2           525         TA          TA          Y           240           0              0               0            0             0          None    MnPrv  None         0         4        2010     WD        Normal         126000
# 2  85           RL        60           7200      Pave   None  Reg       Lvl          AllPub    Inside     Gtl        CollgCr      Norm        Norm        1Fam      SFoyer      5             8             1972        2003            Gable      CompShg   WdShing      HdBoard      None         0            TA         Gd         CBlock     Gd        TA        Av            GLQ            660          Unf            0            108         768           GasA    Gd         Y           SBrkr      768          0            0                768          0              1              1          0          2              1              TA           5              Typ        0           None         Detchd      1974          Fin           1           396         TA          TA          Y           192           0              0               0            0             0          None    MnPrv  None         0         4        2009     WD        Normal         133900

# %% [markdown]
# ### Zamiana wartości `'None'` na 0

# %%
columns1 = ['Lot.Frontage', 
            'Mas.Vnr.Area', 
            'BsmtFin.SF.1',
            'BsmtFin.SF.2',
            'Bsmt.Unf.SF', 
            'Total.Bsmt.SF', 
            'Bsmt.Full.Bath', 
            'Bsmt.Half.Bath', 
            'Garage.Cars',
            'Garage.Yr.Blt',
            'Garage.Area']

# zamieniam wartość 'None' na 0 i zamieniam je na wartości typu 'Int'
data_updated[columns1] = data_updated[columns1].replace(['None'],'0').apply(pd.to_numeric)

# %% [markdown]
# * Teraz zajmę się zmienną`'Garage.Yr.Blt'`

# %%
# sprawdzę gdzie znajduje się kolumna `Garage.Yr.Blt`
data_updated.columns.get_loc("Garage.Yr.Blt")
# Out:
# 58

# %%
# utworzę nową kolumnę którą nazwę 'Garage.Age'
data_updated.insert(59, "Garage.Age", True)
# w kolumenie 'Garage.Age' wiek wpiszę jako 2020, aby od tej wartości odejmować rok budowy
data_updated["Garage.Age"] = 2020

# %%
data_updated.head(3)
# Out:
#    MS.SubClass MS.Zoning  Lot.Frontage  Lot.Area Street Alley Lot.Shape Land.Contour Utilities Lot.Config Land.Slope Neighborhood Condition.1 Condition.2 Bldg.Type House.Style  Overall.Qual  Overall.Cond  Year.Built  Year.Remod.Add Roof.Style Roof.Matl Exterior.1st Exterior.2nd Mas.Vnr.Type  Mas.Vnr.Area Exter.Qual Exter.Cond Foundation Bsmt.Qual Bsmt.Cond Bsmt.Exposure BsmtFin.Type.1  BsmtFin.SF.1 BsmtFin.Type.2  BsmtFin.SF.2  Bsmt.Unf.SF  Total.Bsmt.SF Heating Heating.QC Central.Air Electrical  X1st.Flr.SF  X2nd.Flr.SF  Low.Qual.Fin.SF  Gr.Liv.Area  Bsmt.Full.Bath  Bsmt.Half.Bath  Full.Bath  Half.Bath  Bedroom.AbvGr  Kitchen.AbvGr Kitchen.Qual  TotRms.AbvGrd Functional  Fireplaces Fireplace.Qu Garage.Type  Garage.Yr.Blt  Garage.Age Garage.Finish  Garage.Cars  Garage.Area Garage.Qual Garage.Cond Paved.Drive  Wood.Deck.SF  Open.Porch.SF  Enclosed.Porch  X3Ssn.Porch  Screen.Porch  Pool.Area Pool.QC  Fence Misc.Feature  Misc.Val  Mo.Sold  Yr.Sold Sale.Type Sale.Condition  SalePrice
# 0  120          RL        34            3901      Pave   None  Reg       Lvl          AllPub    Inside     Gtl        NridgHt      Norm        Norm        Twnhs     1Story      6             5             2005        2006            Gable      CompShg   VinylSd      VinylSd      Stone        182           Gd         TA         PConc      Gd        TA        Av            ALQ            866           Unf            0             436          1302           GasA    Ex         Y           SBrkr      1302         0            0                1302         1               0               1          1          1              1              Gd           5              Typ        1           Gd           Attchd      2005           2020        RFn           2            631          TA          TA          Y           110           50             0               0            0             0          None    None   None         0         8        2007     New       Partial        204000
# 1  20           RL        70            8400      Pave   None  Reg       Lvl          AllPub    Corner     Gtl        Nonemes      Norm        Norm        1Fam      1Story      4             5             1970        1970            Gable      CompShg   Plywood      Plywood      None         0             TA         TA         CBlock     TA        TA        No            ALQ            804           Rec            78            0            882            GasA    TA         Y           SBrkr      882          0            0                882          1               0               1          0          2              1              TA           4              Typ        0           None         Attchd      1970           2020        Fin           2            525          TA          TA          Y           240           0              0               0            0             0          None    MnPrv  None         0         4        2010     WD        Normal         126000
# 2  85           RL        60            7200      Pave   None  Reg       Lvl          AllPub    Inside     Gtl        CollgCr      Norm        Norm        1Fam      SFoyer      5             8             1972        2003            Gable      CompShg   WdShing      HdBoard      None         0             TA         Gd         CBlock     Gd        TA        Av            GLQ            660           Unf            0             108          768            GasA    Gd         Y           SBrkr      768          0            0                768          0               1               1          0          2              1              TA           5              Typ        0           None         Detchd      1974           2020        Fin           1            396          TA          TA          Y           192           0              0               0            0             0          None    MnPrv  None         0         4        2009     WD        Normal         133900

# %%
# weryfikuję czy kolumny przechowują ten sam typ danych
print(data_updated["Garage.Yr.Blt"].dtypes)
print(data_updated["Garage.Age"].dtypes)
# Out:
# int64
# int64

# %%
# odejmuję od 2020(tą wartośc wpisałem wcześniej na sztywno) rok budowy, aby otrzymać wiek garażu
data_updated["Garage.Age"] = data_updated["Garage.Age"] - data_updated["Garage.Yr.Blt"]
# w przypadku jeżeli nie było garażu, jego wiek bedzie wpisany jako 2020 zamienię tą wartość na 0
data_updated["Garage.Age"] = data_updated["Garage.Age"].replace([2020], 0)

# %%
# w celu upewnienia się ,że wsztstko gra sprawdze pierwsze wpisy w w kolumnach 'Garage.Yr.Blt' oraz 'Garage.Age'
data_updated[["Garage.Yr.Blt", "Garage.Age"]].head(15)
# Out:
#     Garage.Yr.Blt  Garage.Age
# 0   2005           15
# 1   1970           50
# 2   1974           46
# 3   1979           41
# 4   2006           14
# 5   1946           74
# 6   1976           44
# 7   1952           68
# 8   2000           20
# 9   0              0
# 10  1925           95
# 11  1967           53
# 12  0              0
# 13  1989           31
# 14  1964           56

# %%
# usunę z data setu kolumnę "Garage.Yr.Blt" ponieważ daje tą samą informację co kolumna "Garage.Age"

data_updated = data_updated.drop("Garage.Yr.Blt", axis=1)
data_updated.head(3)
# Out:
#    MS.SubClass MS.Zoning  Lot.Frontage  Lot.Area Street Alley Lot.Shape Land.Contour Utilities Lot.Config Land.Slope Neighborhood Condition.1 Condition.2 Bldg.Type House.Style  Overall.Qual  Overall.Cond  Year.Built  Year.Remod.Add Roof.Style Roof.Matl Exterior.1st Exterior.2nd Mas.Vnr.Type  Mas.Vnr.Area Exter.Qual Exter.Cond Foundation Bsmt.Qual Bsmt.Cond Bsmt.Exposure BsmtFin.Type.1  BsmtFin.SF.1 BsmtFin.Type.2  BsmtFin.SF.2  Bsmt.Unf.SF  Total.Bsmt.SF Heating Heating.QC Central.Air Electrical  X1st.Flr.SF  X2nd.Flr.SF  Low.Qual.Fin.SF  Gr.Liv.Area  Bsmt.Full.Bath  Bsmt.Half.Bath  Full.Bath  Half.Bath  Bedroom.AbvGr  Kitchen.AbvGr Kitchen.Qual  TotRms.AbvGrd Functional  Fireplaces Fireplace.Qu Garage.Type  Garage.Age Garage.Finish  Garage.Cars  Garage.Area Garage.Qual Garage.Cond Paved.Drive  Wood.Deck.SF  Open.Porch.SF  Enclosed.Porch  X3Ssn.Porch  Screen.Porch  Pool.Area Pool.QC  Fence Misc.Feature  Misc.Val  Mo.Sold  Yr.Sold Sale.Type Sale.Condition  SalePrice
# 0  120          RL        34            3901      Pave   None  Reg       Lvl          AllPub    Inside     Gtl        NridgHt      Norm        Norm        Twnhs     1Story      6             5             2005        2006            Gable      CompShg   VinylSd      VinylSd      Stone        182           Gd         TA         PConc      Gd        TA        Av            ALQ            866           Unf            0             436          1302           GasA    Ex         Y           SBrkr      1302         0            0                1302         1               0               1          1          1              1              Gd           5              Typ        1           Gd           Attchd      15          RFn           2            631          TA          TA          Y           110           50             0               0            0             0          None    None   None         0         8        2007     New       Partial        204000
# 1  20           RL        70            8400      Pave   None  Reg       Lvl          AllPub    Corner     Gtl        Nonemes      Norm        Norm        1Fam      1Story      4             5             1970        1970            Gable      CompShg   Plywood      Plywood      None         0             TA         TA         CBlock     TA        TA        No            ALQ            804           Rec            78            0            882            GasA    TA         Y           SBrkr      882          0            0                882          1               0               1          0          2              1              TA           4              Typ        0           None         Attchd      50          Fin           2            525          TA          TA          Y           240           0              0               0            0             0          None    MnPrv  None         0         4        2010     WD        Normal         126000
# 2  85           RL        60            7200      Pave   None  Reg       Lvl          AllPub    Inside     Gtl        CollgCr      Norm        Norm        1Fam      SFoyer      5             8             1972        2003            Gable      CompShg   WdShing      HdBoard      None         0             TA         Gd         CBlock     Gd        TA        Av            GLQ            660           Unf            0             108          768            GasA    Gd         Y           SBrkr      768          0            0                768          0               1               1          0          2              1              TA           5              Typ        0           None         Detchd      46          Fin           1            396          TA          TA          Y           192           0              0               0            0             0          None    MnPrv  None         0         4        2009     WD        Normal         133900

# %% [markdown]
# ### Uzupełniam brakujące wartości
#
# Teraz zajmę się usunięciem brakujących wartości
#
# * Sprawdzam ile jest brakujących wartości. Brakujące wartości przedstawione zostaną w ujęciu procentowym dla każdej zmiennej.

# %%
data_updated.isna().values.sum()
# Out:
# 28

# %%
missing_values = data_updated.isna().sum()

missing_values = missing_values[missing_values > 0]
percent_missing = missing_values * 100 / data_updated.shape[0]

pd.concat([missing_values, percent_missing], axis=1,keys=['Missing Values', 'Percentage of all Missing Values']).sort_values(by="Missing Values", ascending=False)
# Out:
#                 Missing Values  Percentage of all Missing Values
# Mas.Vnr.Type    16              0.80
# Bsmt.Exposure   3               0.15
# BsmtFin.Type.2  2               0.10
# Garage.Finish   2               0.10
# Bsmt.Qual       1               0.05
# Bsmt.Cond       1               0.05
# BsmtFin.Type.1  1               0.05
# Garage.Qual     1               0.05
# Garage.Cond     1               0.05

# %% [markdown]
# W przygotowanym data secie nie ma dużej ilości brakujących wartości dla poszczególnych zmiennych / kolumn.
# Łącznie jest 28 brakującyh wartości.
#
# W pierwszej kolejności zamienie brakujące wartości na string `'None'`

# %%
columns2 = ['Mas.Vnr.Type', 
            'Bsmt.Exposure',
            'BsmtFin.Type.2',
            'Garage.Finish', 
            'Bsmt.Qual', 
            'Bsmt.Cond', 
            'BsmtFin.Type.1', 
            'Garage.Qual', 
            'Garage.Cond']

for values in columns2:
      data_updated[values].fillna("None", inplace=True)

# %%
# sprawdzę teraz czy wciąż występują brakujące wartości 
missing_values = data_updated.isna().sum()
missing_values.sum()
# Out:
# 0

# %% [markdown]
# Zgodnie z dokumentacją nie ma takiej wartości jak 'None' dla zmiennych, w których wystepowały brakujące wartości  (które roboczo zapisałe wcześniej jako `'columns2'`).
#
# W słowniku została przyjęta wartość `'NA'`.  Dlatego w celu zapewnienia zgodności słownika zamienię wartości `'None'` na `'NA'`.
#
# Dodatkowo ta zamiana jest istotna w szczególności dla zmiennych porządkowych dla których później będę te wartości zamieniał na liczby.

# %%
# zamieniam wartość 'None' na 'NA' 
data_updated[columns2] = data_updated[columns2].replace(['None'],'NA')

# %% [markdown]
# Dla zmiennych `'Alley'`, `'Fireplace.Qu'`, `'Garage.Type'`, `'Pool QC'`, `'Fence'`,`'Misc.Feature'` nie było brakujących wartości ale występowały wartości `'None'`, które także zamienię na `'NA'`.
#
# Jest to waże ponieważ dalej zaminię zmienne porządkowe na liczby odpowiadające stopniowaniu.

# %%
columns3 = ['Alley',
            'Fireplace.Qu',
            'Garage.Type',
            'Pool.QC',
            'Fence',
            'Misc.Feature']

data_updated[columns3] = data_updated[columns3].replace(['None'],'NA')

# %% [markdown]
# * Sprawdzę czy w data secie pozostały wartości `'None'`

# %%
data_updated.isin(['None']).sum().sum()
# Out:
# 0

# %%
data_updated.head(3)
# Out:
#    MS.SubClass MS.Zoning  Lot.Frontage  Lot.Area Street Alley Lot.Shape Land.Contour Utilities Lot.Config Land.Slope Neighborhood Condition.1 Condition.2 Bldg.Type House.Style  Overall.Qual  Overall.Cond  Year.Built  Year.Remod.Add Roof.Style Roof.Matl Exterior.1st Exterior.2nd Mas.Vnr.Type  Mas.Vnr.Area Exter.Qual Exter.Cond Foundation Bsmt.Qual Bsmt.Cond Bsmt.Exposure BsmtFin.Type.1  BsmtFin.SF.1 BsmtFin.Type.2  BsmtFin.SF.2  Bsmt.Unf.SF  Total.Bsmt.SF Heating Heating.QC Central.Air Electrical  X1st.Flr.SF  X2nd.Flr.SF  Low.Qual.Fin.SF  Gr.Liv.Area  Bsmt.Full.Bath  Bsmt.Half.Bath  Full.Bath  Half.Bath  Bedroom.AbvGr  Kitchen.AbvGr Kitchen.Qual  TotRms.AbvGrd Functional  Fireplaces Fireplace.Qu Garage.Type  Garage.Age Garage.Finish  Garage.Cars  Garage.Area Garage.Qual Garage.Cond Paved.Drive  Wood.Deck.SF  Open.Porch.SF  Enclosed.Porch  X3Ssn.Porch  Screen.Porch  Pool.Area Pool.QC  Fence Misc.Feature  Misc.Val  Mo.Sold  Yr.Sold Sale.Type Sale.Condition  SalePrice
# 0  120          RL        34            3901      Pave   NA    Reg       Lvl          AllPub    Inside     Gtl        NridgHt      Norm        Norm        Twnhs     1Story      6             5             2005        2006            Gable      CompShg   VinylSd      VinylSd      Stone        182           Gd         TA         PConc      Gd        TA        Av            ALQ            866           Unf            0             436          1302           GasA    Ex         Y           SBrkr      1302         0            0                1302         1               0               1          1          1              1              Gd           5              Typ        1           Gd           Attchd      15          RFn           2            631          TA          TA          Y           110           50             0               0            0             0          NA      NA     NA           0         8        2007     New       Partial        204000
# 1  20           RL        70            8400      Pave   NA    Reg       Lvl          AllPub    Corner     Gtl        Nonemes      Norm        Norm        1Fam      1Story      4             5             1970        1970            Gable      CompShg   Plywood      Plywood      NA           0             TA         TA         CBlock     TA        TA        No            ALQ            804           Rec            78            0            882            GasA    TA         Y           SBrkr      882          0            0                882          1               0               1          0          2              1              TA           4              Typ        0           NA           Attchd      50          Fin           2            525          TA          TA          Y           240           0              0               0            0             0          NA      MnPrv  NA           0         4        2010     WD        Normal         126000
# 2  85           RL        60            7200      Pave   NA    Reg       Lvl          AllPub    Inside     Gtl        CollgCr      Norm        Norm        1Fam      SFoyer      5             8             1972        2003            Gable      CompShg   WdShing      HdBoard      NA           0             TA         Gd         CBlock     Gd        TA        Av            GLQ            660           Unf            0             108          768            GasA    Gd         Y           SBrkr      768          0            0                768          0               1               1          0          2              1              TA           5              Typ        0           NA           Detchd      46          Fin           1            396          TA          TA          Y           192           0              0               0            0             0          NA      MnPrv  NA           0         4        2009     WD        Normal         133900

# %% [markdown]
# ## Wartości porządkowe tzw. Ordinal Values

# %% [markdown]
# W data secie wystepują zmienne dla których przyjęte są zmienne porządkowe, tzw. ***ordinal values***, będące zmiennymi kategorycznymi. Są to wartości, które przedstawiają stopniowanie.
# Dla przykładu, przedstawię unikalne wartości dla zmiennej `'External.Qual'`

# %%
data_updated['Exter.Qual'].unique()
# Out:
# array(['Gd', 'TA', 'Ex', 'Fa'], dtype=object)

# %% [markdown]
# Zgodnie z dokumentacją wynika, że wartości dla zmiennej `'Exter.Qual'`oznaczają:
# * `'Ex'` - Excellent
# * `'Gd'` - Good
# * `'TA'` - Average/Typical
# * `'Fa'` - Fair
# * `'Po'` - Poor
#
# Jeżeli wykorzystamy sposób zamiany tych wartości kategorycznych na numeryczne jak w przypadku inncyh wartości kategorycznych model nie będzie wiedział, że te wartości odzwierciedlają stopniowanie.
#
# Aby uniknąć tego problemu zamienię wartości porządkowe (kategoryczne) na numeryczne odzwierciedlające ranking. Czyli dla wartości `'NA'` przyjmiemy `0`, dla wartości `'Po'` - `1`, dla wartości `'Fa'` - `2` itd.
#
# Zgodnie z dokumentacją wartości porządkowe przyjmują następujące zmienne:
#
# `'Lot.Shape'`, `'Land.Slope'`, `'Electrical'`, `'Exter Qual'`, `'Exter Cond'`, `'Bsmt Qual'`, `'Bsmt Cond'`, `'Bsmt Exposure'`, `'BsmtFin Type 1'`, `'BsmtFinType 2'`, `'HeatingQC'`, `'Central Air'`, `'KitchenQual'`, `'FireplaceQu'`, `'Garage Finish'`, `'Garage Qual'`, `'Garage Cond'`, `'Pool QC'`, `'Fence'`

# %%
map_1 = {'Reg':3,'IR1':2,'IR2':1,'IR3':0}
data_updated['Lot.Shape'] = data_updated['Lot.Shape'].map(map_1)

map_2 = {'Gtl':2,'Mod':1,'Sev':0}
data_updated['Land.Slope'] = data_updated['Land.Slope'].map(map_2)

map_3 = {'Ex':4,'Gd':3,'TA':2,'Fa':1,'Po':0}
data_updated['Exter.Qual'] = data_updated['Exter.Qual'].map(map_3)
data_updated['Exter.Cond'] = data_updated['Exter.Cond'].map(map_3)
data_updated['Heating.QC'] = data_updated['Heating.QC'].map(map_3)
data_updated['Kitchen.Qual'] = data_updated['Kitchen.Qual'].map(map_3)

map_4 = {'SBrkr':4, 'FuseA':3, 'FuseF':2,'FuseP':1,'Mix':0}
data_updated['Electrical'] = data_updated['Electrical'].map(map_4)

map_5 = {'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1,'NA':0}
data_updated['Bsmt.Qual'] = data_updated['Bsmt.Qual'].map(map_5)
data_updated['Bsmt.Cond'] = data_updated['Bsmt.Cond'].map(map_5)

map_6 = {'Gd':4,'Av':3,'Mn':2,'No':1,'NA':0}
data_updated['Bsmt.Exposure'] = data_updated['Bsmt.Exposure'].map(map_6)

map_7 = {'GLQ':6,'ALQ':5,'BLQ':4,'Rec':3,'LwQ':2,'Unf':1,'NA':0}
data_updated['BsmtFin.Type.1'] = data_updated['BsmtFin.Type.1'].map(map_7)
data_updated['BsmtFin.Type.2'] = data_updated['BsmtFin.Type.2'].map(map_7)

map_8 = {'Y':1,'N':0}
data_updated['Central.Air'] = data_updated['Central.Air'].map(map_8)

map_9 = {'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1,'NA':0}
data_updated['Fireplace.Qu'] = data_updated['Fireplace.Qu'].map(map_9)

map_10 = {'Fin':3,'RFn':2,'Unf':1,'NA':0}
data_updated['Garage.Finish'] = data_updated['Garage.Finish'].map(map_10)

map_11 = {'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1,'NA':0}
data_updated['Garage.Qual'] = data_updated['Garage.Qual'].map(map_11)
data_updated['Garage.Cond'] = data_updated['Garage.Cond'].map(map_11)

map_12 = {'Ex':4,'Gd':3,'TA':2,'Fa':1,'NA':0}
data_updated['Pool.QC'] = data_updated['Pool.QC'].map(map_12)

map_13 = {'GdPrv':4,'MnPrv':3,'GdWo':2,'MnWw':1,'NA':0}
data_updated['Fence'] = data_updated['Fence'].map(map_13)

# %% [markdown]
# *  Sprawdzę teraz jakie kolumny przyjmują wartości numerczne

# %%
data_num_updated = data_updated.select_dtypes('number')
pd.DataFrame(data_num_updated.columns)
# Out:
#                   0
# 0   MS.SubClass
# 1   Lot.Frontage
# 2   Lot.Area
# 3   Lot.Shape
# 4   Land.Slope
# 5   Overall.Qual
# 6   Overall.Cond
# 7   Year.Built
# 8   Year.Remod.Add
# 9   Mas.Vnr.Area
# 10  Exter.Qual
# 11  Exter.Cond
# 12  Bsmt.Qual
# 13  Bsmt.Cond
# 14  Bsmt.Exposure
# 15  BsmtFin.Type.1
# 16  BsmtFin.SF.1
# 17  BsmtFin.Type.2
# 18  BsmtFin.SF.2
# 19  Bsmt.Unf.SF
# 20  Total.Bsmt.SF
# 21  Heating.QC
# 22  Central.Air
# 23  Electrical
# 24  X1st.Flr.SF
# 25  X2nd.Flr.SF
# 26  Low.Qual.Fin.SF
# 27  Gr.Liv.Area
# 28  Bsmt.Full.Bath
# 29  Bsmt.Half.Bath
# 30  Full.Bath
# 31  Half.Bath
# 32  Bedroom.AbvGr
# 33  Kitchen.AbvGr
# 34  Kitchen.Qual
# 35  TotRms.AbvGrd
# 36  Fireplaces
# 37  Fireplace.Qu
# 38  Garage.Age
# 39  Garage.Finish
# 40  Garage.Cars
# 41  Garage.Area
# 42  Garage.Qual
# 43  Garage.Cond
# 44  Wood.Deck.SF
# 45  Open.Porch.SF
# 46  Enclosed.Porch
# 47  X3Ssn.Porch
# 48  Screen.Porch
# 49  Pool.Area
# 50  Pool.QC
# 51  Fence
# 52  Misc.Val
# 53  Mo.Sold
# 54  Yr.Sold
# 55  SalePrice

# %% [markdown]
# Jak widać teraz już większość zmiennych przyjmuje wartości numeryczne.
#
# Przystąpię to zwizualizowania danych.

# %% [markdown]
# ***

# %% [markdown]
# ### **Wizualizacja danych**
#
# W danych nie ma już brakującyh wartości. Teraz w celu lepszego zrozumienia danych oraz sprawdzenia czy w data secie wystepują wartości odstające wykonam kilka wizualizacji.
# <br>W pierwszej kolejności wybieram tylko zminne z wartościami numerycznymi i sprawdzę jaka jest ich korelacja ze zmianną celu `'Sale.Price'`

# %%
data_num = data_updated.select_dtypes('number')
pd.DataFrame(data_num.columns)
# Out:
#                   0
# 0   MS.SubClass
# 1   Lot.Frontage
# 2   Lot.Area
# 3   Lot.Shape
# 4   Land.Slope
# 5   Overall.Qual
# 6   Overall.Cond
# 7   Year.Built
# 8   Year.Remod.Add
# 9   Mas.Vnr.Area
# 10  Exter.Qual
# 11  Exter.Cond
# 12  Bsmt.Qual
# 13  Bsmt.Cond
# 14  Bsmt.Exposure
# 15  BsmtFin.Type.1
# 16  BsmtFin.SF.1
# 17  BsmtFin.Type.2
# 18  BsmtFin.SF.2
# 19  Bsmt.Unf.SF
# 20  Total.Bsmt.SF
# 21  Heating.QC
# 22  Central.Air
# 23  Electrical
# 24  X1st.Flr.SF
# 25  X2nd.Flr.SF
# 26  Low.Qual.Fin.SF
# 27  Gr.Liv.Area
# 28  Bsmt.Full.Bath
# 29  Bsmt.Half.Bath
# 30  Full.Bath
# 31  Half.Bath
# 32  Bedroom.AbvGr
# 33  Kitchen.AbvGr
# 34  Kitchen.Qual
# 35  TotRms.AbvGrd
# 36  Fireplaces
# 37  Fireplace.Qu
# 38  Garage.Age
# 39  Garage.Finish
# 40  Garage.Cars
# 41  Garage.Area
# 42  Garage.Qual
# 43  Garage.Cond
# 44  Wood.Deck.SF
# 45  Open.Porch.SF
# 46  Enclosed.Porch
# 47  X3Ssn.Porch
# 48  Screen.Porch
# 49  Pool.Area
# 50  Pool.QC
# 51  Fence
# 52  Misc.Val
# 53  Mo.Sold
# 54  Yr.Sold
# 55  SalePrice

# %%
corr = data_num.corr()
print (corr['SalePrice'].sort_values(ascending=False)[:10], '\n')
print (corr['SalePrice'].sort_values(ascending=False)[-10:])
# Out:
# SalePrice        1.000000
# Overall.Qual     0.804547
# Gr.Liv.Area      0.720922
# Exter.Qual       0.691842
# Kitchen.Qual     0.668868
# Garage.Cars      0.641155
# Garage.Area      0.628159
# Total.Bsmt.SF    0.623371
# X1st.Flr.SF      0.619121
# Bsmt.Qual        0.616290
# Name: SalePrice, dtype: float64
#
# Bsmt.Half.Bath    -0.032198
# Low.Qual.Fin.SF   -0.051056
# Land.Slope        -0.061219
# MS.SubClass       -0.075202
# Overall.Cond      -0.120190
# Enclosed.Porch    -0.128352
# Kitchen.AbvGr     -0.129682
# Fence             -0.157293
# Lot.Shape         -0.285217
# Garage.Age        -0.391001
# Name: SalePrice, dtype: float64

# %% [markdown]
# Jak widać zmienna `'Sale.Price'` jest mocno skorelowana ze zmiennymi `'Overall.Qual'`, `'Gr.Liv.Area'`, `'Exter.Qual'`, `'Kitchen.Qual'`, `'Garage.Cars'`, `'Garage.Area'`, `'Total.Bsmt.SF'`, `'X1st.Flr.SF'`, `'Bsmt.Qual'`.
#
# Wykonam wizualizację zależności między zmiennymi, skupiam się na wizualizacji między zmienną `'Sale.Price'` a zmiennymi, które przyjmują szeroki zakres wartości.

# %%
from matplotlib import pyplot as plt

# %%
plt.subplots(figsize=(15,18))

# wykres 1 cena vs jakość
plt.subplot(321)
plt.scatter(x=data_updated['Overall.Qual'], 
            y=data_updated['SalePrice'], 
            color="green", 
            edgecolors="#000000", 
            linewidths=0.5);

plt.xlabel("Overall.Qual"); 
plt.ylabel("SalePrice");
plt.title("Sales Price vs. Overall Quality");


# wykres 2 cena vs powierzchnia
plt.subplot(322)
plt.scatter(x=data_updated['Gr.Liv.Area'], 
            y=data_updated['SalePrice'], 
            color="green", 
            edgecolors="#000000", 
            linewidths=0.5);

plt.xlabel("Gr.Liv.Area"); 
plt.ylabel("SalePrice");
plt.title("Sales Price vs. Gr.Living Area");

# wykres 3 cena vs powierzchnia garażu
plt.subplot(323)
plt.scatter(x=data_updated['Garage.Area'], 
            y=data_updated['SalePrice'], 
            color="green", 
            edgecolors="#000000", 
            linewidths=0.5);

plt.xlabel("Garage.Area"); 
plt.ylabel("SalePrice");
plt.title("Sales Price vs. Garage Area");

# wykres 4 cena vs powierzchnia piwnicy
plt.subplot(324)
plt.scatter(x=data_updated['Total.Bsmt.SF'], 
            y=data_updated['SalePrice'], 
            color="green", 
            edgecolors="#000000", 
            linewidths=0.5);

plt.xlabel("Total.Bsmt.SF"); 
plt.ylabel("SalePrice");
plt.title("Sales Price vs. Total Bsmt SF")

# wykres 5 cena vs powierzchnia 1st piętra
plt.subplot(325)
plt.scatter(x=data_updated['X1st.Flr.SF'], 
            y=data_updated['SalePrice'], 
            color="green", 
            edgecolors="#000000", 
            linewidths=0.5);

plt.xlabel("X1st.Flr.SF"); 
plt.ylabel("SalePrice");
plt.title("Sales Price vs. 1st floor SF")

# wykres 6 cena vs rok budowy
plt.subplot(326)
plt.scatter(x=data_updated['Year.Built'], 
            y=data_updated['SalePrice'], 
            color="green", 
            edgecolors="#000000", 
            linewidths=0.5);

plt.xlabel("Year.Built"); 
plt.ylabel("SalePrice");
plt.title("Sales Price vs. Built Year")

plt.show()

# %% [markdown]
# Powyższa wizualizacja pokazuje pozytywną korelację miedzy zminną`'Sale.Price'` a pozostałymi zmiennymi.
#
# Na wykresie **"Sales Price vs. Gr.Living Area"** Widać że trzy obserwacje odstają od reszty. Obserwacje gdzie zmienna `'Gr.Liv.Area'` jest większa niż 4000 odstają ewidentnie od reszty obserwacji.
#
# Podobnie jest na wykresie **Sales Price vs  Total Bsmt SF'**. Obserwacje dla których wartość zmiennej `'Total.Bsmt.SF'` jest większa niż 3000 odstają od reszty.
#
# Powyższa wizualizacja pokazuje, że obseracje dla których zmienna`'Garage.Area'` jest większa niż 1300 sq ft także odstają od reszty obserwacji.
#
# Widać także, że jedna obseracja  dla zmiennej`'X1st.Flr.SF'`. Widać także, że jedna obseracja odstaje od data setu.
#
# Zajmę się usunięciem wartości odstających.

# %% [markdown]
# * Zajmę się teraz usunnięciem odstających wartości.

# %%
data_updated = data_updated[data_updated["Gr.Liv.Area"] < 4000]
data_updated = data_updated[data_updated["Garage.Area"] < 1300]
data_updated = data_updated[data_updated["Total.Bsmt.SF"] < 4000]

# %% [markdown]
# W celu zweryfikowania czy wskazane wartości dla zmiennej `'Gr.Liv.Area'`, `'Garage.Area'`, `'Total.Bsmt.SF'` zostały usunięty raz jeszcze wykonam wizualizacje.

# %%
plt.subplots(figsize=(13,15))

# wykres 1 cena vs jakość
plt.subplot(221)
plt.scatter(x=data_updated['Overall.Qual'], 
            y=data_updated['SalePrice'], 
            color="green", 
            edgecolors="#000000", 
            linewidths=0.5);

plt.xlabel("Overall.Qual"); 
plt.ylabel("SalePrice");
plt.title("Sales Price vs. Overall Quality");


# wykres 2 cena vs powierzchnia
plt.subplot(222)
plt.scatter(x=data_updated['Gr.Liv.Area'], 
            y=data_updated['SalePrice'], 
            color="green", 
            edgecolors="#000000", 
            linewidths=0.5);

plt.xlabel("Gr.Liv.Area"); 
plt.ylabel("SalePrice");
plt.title("Sales Price vs. Gr.Living Area");

# wykres 3 cena vs powierzchnia garażu
plt.subplot(223)
plt.scatter(x=data_updated['Garage.Area'], 
            y=data_updated['SalePrice'], 
            color="green", 
            edgecolors="#000000", 
            linewidths=0.5);

plt.xlabel("Garage.Area"); 
plt.ylabel("SalePrice");
plt.title("Sales Price vs. Garage Area");

# wykres 4 cena vs powierzchnia piwnicy
plt.subplot(224)
plt.scatter(x=data_updated['Total.Bsmt.SF'], 
            y=data_updated['SalePrice'], 
            color="green", 
            edgecolors="#000000", 
            linewidths=0.5);

plt.xlabel("Total.Bsmt.SF"); 
plt.ylabel("SalePrice");
plt.title("Sales Price vs. Total Bsmt SF")

plt.show()

# %%
data_updated.reset_index(drop=True, inplace=True) # zresetowałem indexy w dataframe po usunięciu obserwacji odstających

# %% [markdown]
# ## **4. Eksploracyjna analiza danych**

# %% [markdown]
# W tej sekcji w celu zrozumienia zależności między zmiennymi wykonam kolejne wizualizacje. Odpowiednie zrozumienie zależności między danymi pomoże w wykonaniu lepszego modelu.
# * W pierwsze kolejności zajmę się analizą dystrybucji zmiennej objaśnianej.

# %%
plt.subplots(figsize=(9,18))

# wykres 1 - histogram
plt.subplot(311)
plt.hist(data_updated['SalePrice'], 
         bins = 8)

plt.xlabel("SalePrice")
plt.ylabel("Ilość wystapień")
plt.grid(True)
plt.title('Histogram dla zmiennej objaśnianej SalePrice')

# wykres 2 - boxplot
plt.subplot(312)
plt.boxplot(data_updated['SalePrice'],
            positions=[1],
            whis=10,
            widths=0.9,
            patch_artist = True) 

plt.ylabel("SalePrice")
plt.grid(True)
plt.title('Dystrybucja zmiennej objaśnianej "SalePrice"')

# wykres 3 - violin plot
plt.subplot(313)
plt.violinplot(data_updated['SalePrice']) 
plt.ylabel("SalePrice")
plt.grid(True)
plt.title('Dystrybucja zmiennej objaśnianej "SalePrice"') 

plt.show()

# %% [markdown]
# Za pomocą pierwszego wykresu (histogram) widać jak rozkłada się zmienna objaśniana `'SalePrice'`. Zmienna ta przyjmowała najczęściej wartości z przedziału 100 000 - 250 000. Potiwerdza to także wykres trzeci.
#
# Na drugim wykresie (wykres pudełkowy)  zaznaczone są minimalna i maksymalna wartości zmiennej `'SalePrice'` oraz mediana oraz pierwszy i trzeci kwartyl.

# %% [markdown]
# ### Analiza korelacji miedzy zmiennymi
#
# <br> W tym celu za pomocą funkcji `df.corr()` pokażę zależności miedzy kolumnami. Pokazane zostaną ***tylko zależności między wartościami numerycznymi***. Wartość im bliższa 1 tym silniesza zależność miedzy zmiennymi. Wykorzystana metoda to korelacja Persona służąca do badania liniowej zależności między danymi.
#
# Interpretacja:
# - < 0.2 – brak związku liniowego
# - 0.2 – 0.4 – słaba zależność
# - 0.4 -0.7 – umiarkowana zależność
# - 0.7 – 0.9 – dość silna zależność
# - więcej niż 0.9 – bardzo silna zależność

# %%
print("=====================================")
print("Correlation Matrix")
print("=====================================")
corr = data_updated.corr(method ='pearson').sort_values("SalePrice")

corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# =====================================
# Correlation Matrix
# =====================================
# <style  type="text/css" >
# #T_db925d44_3749_11eb_82b7_086d41d7ecaerow0_col0,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow1_col45,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow4_col41,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow12_col52,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow14_col32,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow17_col11,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow25_col48,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow25_col50,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow26_col48,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow32_col49,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow37_col26,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow38_col26,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow39_col51,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow49_col51,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow51_col3,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow52_col38,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow54_col29,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow54_col48,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow55_col29,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow55_col49,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow55_col50{
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_db925d44_3749_11eb_82b7_086d41d7ecaerow0_col1,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow1_col30,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow2_col1,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow2_col23,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow2_col54,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow2_col55,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow3_col20,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow4_col24,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow5_col54,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow8_col22,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow9_col9,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow9_col25,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow9_col42,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow10_col42,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow11_col17,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow11_col27,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow12_col44,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow12_col45,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow12_col54,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow13_col1,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow14_col37,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow15_col17,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow16_col9,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow17_col26,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow21_col23,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow21_col53,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow23_col3,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow24_col54,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow29_col1,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow30_col54,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow37_col11,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow38_col53,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow41_col0,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow50_col0{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_db925d44_3749_11eb_82b7_086d41d7ecaerow0_col2,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow2_col28,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow7_col12,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow8_col7,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow10_col15,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow15_col12,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow15_col15,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow15_col21,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow17_col12,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow17_col30,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow17_col34,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow17_col55,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow18_col2,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow18_col5,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow18_col12,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow18_col30,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow20_col24,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow21_col32,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow24_col24,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow31_col15,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow31_col45,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow36_col22,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow40_col25,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow40_col31,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow45_col4,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow49_col42,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow51_col2,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow53_col1{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }#T_db925d44_3749_11eb_82b7_086d41d7ecaerow0_col3,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow12_col16,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow16_col10,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow18_col10,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow18_col16,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow20_col31,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow21_col13,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow25_col19,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow26_col19,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow29_col38,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow30_col21,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow31_col0,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow31_col41,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow32_col15,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow32_col35,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow33_col37,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow38_col25,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow39_col16,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow41_col38,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow41_col43,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow41_col45,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow42_col25,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow43_col33,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow43_col36,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow45_col45,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow48_col13,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow48_col45,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow49_col1,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow50_col13,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow52_col23,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow52_col31{
#             background-color:  #adc9fd;
#             color:  #000000;
#         }#T_db925d44_3749_11eb_82b7_086d41d7ecaerow0_col4,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow0_col17,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow0_col28,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow1_col8,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow5_col18,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow7_col28,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow8_col15,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow8_col25,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow8_col33,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow8_col35,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow11_col51,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow12_col43,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow16_col40,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow16_col41,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow17_col13,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow17_col14,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow17_col44,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow18_col1,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow18_col13,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow18_col36,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow18_col39,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow19_col43,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow21_col37,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow22_col13,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow24_col17,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow28_col17,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow33_col4,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow36_col6,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow39_col23{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_db925d44_3749_11eb_82b7_086d41d7ecaerow0_col5,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow0_col7,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow0_col8,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow0_col9,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow0_col10,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow0_col12,#T_db925d44_3749_11eb_82b7_086d41d7ecaerow0_col

# %%
corr = data_updated.corr()
print (corr['SalePrice'].sort_values(ascending=False)[:15], '\n')
print (corr['SalePrice'].sort_values(ascending=False)[-25:])
# Out:
# SalePrice         1.000000
# Overall.Qual      0.810587
# Gr.Liv.Area       0.723282
# Exter.Qual        0.700422
# Kitchen.Qual      0.672093
# Garage.Cars       0.648838
# Total.Bsmt.SF     0.642079
# Garage.Area       0.640870
# X1st.Flr.SF       0.627639
# Bsmt.Qual         0.622919
# Year.Built        0.581983
# Garage.Finish     0.566629
# Full.Bath         0.559488
# Year.Remod.Add    0.546223
# Fireplace.Qu      0.538340
# Name: SalePrice, dtype: float64
#
# Electrical         0.238570
# Bsmt.Cond          0.221978
# Lot.Frontage       0.216489
# Bsmt.Unf.SF        0.167379
# Bedroom.AbvGr      0.147534
# Screen.Porch       0.093394
# Pool.QC            0.049135
# Pool.Area          0.041733
# Mo.Sold            0.038027
# X3Ssn.Porch        0.032176
# BsmtFin.SF.2       0.007557
# BsmtFin.Type.2     0.005183
# Exter.Cond        -0.009371
# Misc.Val          -0.011141
# Yr.Sold           -0.025459
# Bsmt.Half.Bath    -0.047643
# Low.Qual.Fin.SF   -0.051646
# Land.Slope        -0.065453
# MS.SubClass       -0.076180
# Overall.Cond      -0.123596
# Enclosed.Porch    -0.130507
# Kitchen.AbvGr     -0.131702
# Fence             -0.168409
# Lot.Shape         -0.289791
# Garage.Age        -0.397264
# Name: SalePrice, dtype: float64

# %% [markdown]
# ### Wykorzystanie biblioteki pandas profiling
# Dodatkowowo w ramach exploracyjnej anlizy danych wykorzystałem dedykowaną biblioteka do komplekswej analizy danych. Biblioteka nazywa się Pandas Profiling Report.
# <br>Wynik analizy jest przedstawiany w iframe w notebooku, więc nie będzie czytelny na GitHub. Wynik analizy można zapisać dopliku .html.
#
# Wynik analizy pokrywa działania, które wykonałem samodzielnie w związku z czym wynik anlizy  wykonanej za pomocą biblioteki Panda Profiling Report nie będą zawarte w ramach tego notebooka.

# %%
#from pandas_profiling import ProfileReport

#profile = ProfileReport(data_updated, title='Pandas Profiling Report')

# %%
#profile.to_notebook_iframe()

# %%
#profile.to_file("Profiling_report.html")

# %% [markdown]
# #### Wnioski i przygotowanie danych do modelowania

# %% [markdown]
# Na podstawie przeprowadzonej eksploracyjnej analizy danych widać, że niektóre zmienne nie mają istotnego wpływy na zmienną celu `'Sale.Price'`. Dlatego też przed przystąpieniem do modelowania usunę nieistotne zmienne.
#
# Zmienne, które usunę to:
#
#     - 'Utilities',
#     - 'Bsmt.Unf.SF',
#     - 'Bedroom.AbvGr',
#     - 'Screen.Porch',
#     - 'Pool.QC',
#     - 'Pool.Area',
#     - 'Mo.Sold',
#     - 'X3Ssn.Porch',
#     - 'BsmtFin.SF.2',
#     - 'BsmtFin.Type.2',
#     - 'Exter.Cond',
#     - 'Misc.Val',
#     - 'Yr.Sold',
#     - 'Bsmt.Half.Bath',
#     - 'Low.Qual.Fin.SF',
#     - 'Land.Slope',
#     - 'MS.SubClass',
#     - 'Overall.Cond',
#     - 'Enclosed.Porch',
#     - 'Kitchen.AbvGr',
#     - 'Fence',
#     - 'Lot.Shape',
#     - 'Garage.Age'
#
# Data set, w którym pominę wyminione zminne nazwę jako `'data_for_modeling'`

# %%
drop_list = ['Utilities',
             'Bsmt.Unf.SF',
             'Bedroom.AbvGr',
             'Screen.Porch',
             'Pool.QC',
             'Pool.Area',
             'Mo.Sold',
             'X3Ssn.Porch',
             'BsmtFin.SF.2',
             'BsmtFin.Type.2',
             'Exter.Cond',
             'Misc.Val',
             'Yr.Sold',
             'Bsmt.Half.Bath',
             'Low.Qual.Fin.SF',
             'Land.Slope',
             'MS.SubClass',
             'Overall.Cond',
             'Enclosed.Porch',
             'Kitchen.AbvGr',
             'Fence',
             'Lot.Shape',
             'Garage.Age']

print(len(drop_list))
# Out:
# 23

# %%
data_for_modeling = data_updated.drop(drop_list, axis=1)
data_for_modeling.head(3)
# Out:
#   MS.Zoning  Lot.Frontage  Lot.Area Street Alley Land.Contour Lot.Config Neighborhood Condition.1 Condition.2 Bldg.Type House.Style  Overall.Qual  Year.Built  Year.Remod.Add Roof.Style Roof.Matl Exterior.1st Exterior.2nd Mas.Vnr.Type  Mas.Vnr.Area  Exter.Qual Foundation  Bsmt.Qual  Bsmt.Cond  Bsmt.Exposure  BsmtFin.Type.1  BsmtFin.SF.1  Total.Bsmt.SF Heating  Heating.QC  Central.Air  Electrical  X1st.Flr.SF  X2nd.Flr.SF  Gr.Liv.Area  Bsmt.Full.Bath  Full.Bath  Half.Bath  Kitchen.Qual  TotRms.AbvGrd Functional  Fireplaces  Fireplace.Qu Garage.Type  Garage.Finish  Garage.Cars  Garage.Area  Garage.Qual  Garage.Cond Paved.Drive  Wood.Deck.SF  Open.Porch.SF Misc.Feature Sale.Type Sale.Condition  SalePrice
# 0  RL        34            3901      Pave   NA    Lvl          Inside     NridgHt      Norm        Norm        Twnhs     1Story      6             2005        2006            Gable      CompShg   VinylSd      VinylSd      Stone        182           3           PConc      4          3          3              5               866           1302           GasA    4           1            4           1302         0            1302         1               1          1          3             5              Typ        1           4             Attchd      2              2            631          3            3            Y           110           50             NA           New       Partial        204000
# 1  RL        70            8400      Pave   NA    Lvl          Corner     Nonemes      Norm        Norm        1Fam      1Story      4             1970        1970            Gable      CompShg   Plywood      Plywood      NA           0             2           CBlock     3          3          1              5               804           882            GasA    2           1            4           882          0            882          1               1          0          2             4              Typ        0           0             Attchd      3              2            525          3            3            Y           240           0              NA           WD        Normal         126000
# 2  RL        60            7200      Pave   NA    Lvl          Inside     CollgCr      Norm        Norm        1Fam      SFoyer      5             1972        2003            Gable      CompShg   WdShing      HdBoard      NA           0             2           CBlock     4          3          3              6               660           768            GasA    3           1            4           768          0            768          0               1          0          2             5              Typ        0           0             Detchd      3              1            396          3            3            Y           192           0              NA           WD        Normal         133900

# %% [markdown]
# w ramch realizacji projektu dane do modelowania zapisałem w osobnym pliku i w osobym notebooku wykonałem modelowanie. W projkcie finalnym część dotycząca modelowania jest zawarta w jednym notbooku

# %%
# data_for_modeling.to_csv('data_for_modeling.csv', sep=',', index=False, header=True)

# %% [markdown]
# ## **5. Metody Modelowania**

# %% [markdown]
# W tej skecji wytrenuję kilka modeli:
#
# - Regresja Liniowa
# - Elastic Net
# - Regresja Ridge
# - Regresia Lasso
# - Random Forest
# - Gradient Boosting
#
# Wykonam także wizualizacje w celu dokonania oceny graficznej predykcji wybranych modeli oraz porównam ich wyniki.

# %% [markdown]
# Przed przystąpieniem do modelowania pozostałe dane kategoryczne zamienię na dane numeryczne. Wykorzystam do tego modułu`'LabelEncoder'`

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing

# %%
# wczytuję listę kolumn gdzie wystepują dane kategoryczne
data_cat = list(data_for_modeling.select_dtypes(exclude=["number", 'float']).columns)
data_cat
# Out:
# ['MS.Zoning',
#  'Street',
#  'Alley',
#  'Land.Contour',
#  'Lot.Config',
#  'Neighborhood',
#  'Condition.1',
#  'Condition.2',
#  'Bldg.Type',
#  'House.Style',
#  'Roof.Style',
#  'Roof.Matl',
#  'Exterior.1st',
#  'Exterior.2nd',
#  'Mas.Vnr.Type',
#  'Foundation',
#  'Heating',
#  'Functional',
#  'Garage.Type',
#  'Paved.Drive',
#  'Misc.Feature',
#  'Sale.Type',
#  'Sale.Condition']

# %%
for i in data_cat:
    data_for_modeling[i] = preprocessing.LabelEncoder().fit_transform(data_for_modeling[i].astype('str'))

# %%
# sprawdzam czy zadziałał LabelEncoder w pierwszej kolejności dla kolumn gdzie były wartości kategoryczne
data_for_modeling[data_cat].head(3)
# Out:
#    MS.Zoning  Street  Alley  Land.Contour  Lot.Config  Neighborhood  Condition.1  Condition.2  Bldg.Type  House.Style  Roof.Style  Roof.Matl  Exterior.1st  Exterior.2nd  Mas.Vnr.Type  Foundation  Heating  Functional  Garage.Type  Paved.Drive  Misc.Feature  Sale.Type  Sale.Condition
# 0  5          1       1      3             4           18            2            2            3          2            1           0          11            13            4             2           1        6           1            2            1             6          5
# 1  5          1       1      3             0           17            2            2            0          2            1           0          8             10            3             1           1        6           1            2            1             9          4
# 2  5          1       1      3             4           5             2            2            0          6            1           0          13            6             3             1           1        6           5            2            1             9          4

# %%
# wczytam jeszcze raz cały zestaw danych, aby się upewnić czy nie ma danych kategorycznych
data_for_modeling.head(3)
# Out:
#    MS.Zoning  Lot.Frontage  Lot.Area  Street  Alley  Land.Contour  Lot.Config  Neighborhood  Condition.1  Condition.2  Bldg.Type  House.Style  Overall.Qual  Year.Built  Year.Remod.Add  Roof.Style  Roof.Matl  Exterior.1st  Exterior.2nd  Mas.Vnr.Type  Mas.Vnr.Area  Exter.Qual  Foundation  Bsmt.Qual  Bsmt.Cond  Bsmt.Exposure  BsmtFin.Type.1  BsmtFin.SF.1  Total.Bsmt.SF  Heating  Heating.QC  Central.Air  Electrical  X1st.Flr.SF  X2nd.Flr.SF  Gr.Liv.Area  Bsmt.Full.Bath  Full.Bath  Half.Bath  Kitchen.Qual  TotRms.AbvGrd  Functional  Fireplaces  Fireplace.Qu  Garage.Type  Garage.Finish  Garage.Cars  Garage.Area  Garage.Qual  Garage.Cond  Paved.Drive  Wood.Deck.SF  Open.Porch.SF  Misc.Feature  Sale.Type  Sale.Condition  SalePrice
# 0  5          34            3901      1       1      3             4           18            2            2            3          2            6             2005        2006            1           0          11            13            4             182           3           2           4          3          3              5               866           1302           1        4           1            4           1302         0            1302         1               1          1          3             5              6           1           4             1            2              2            631          3            3            2            110           50             1             6          5               204000
# 1  5          70            8400      1       1      3             0           17            2            2            0          2            4             1970        1970            1           0          8             10            3             0             2           1           3          3          1              5               804           882            1        2           1            4           882          0            882          1               1          0          2             4              6           0           0             1            3              2            525          3            3            2            240           0              1             9          4               126000
# 2  5          60            7200      1       1      3             4           5             2            2            0          6            5             1972        2003            1           0          13            6             3             0             2           1           4          3          3              6               660           768            1        3           1            4           768          0            768          0               1          0          2             5              6           0           0             5            3              1            396          3            3            2            192           0              1             9          4               133900

# %% [markdown]
# ***
# W pierwszym kroku zajmę się podziałem data setu na zestaw treningowy i testowy. Znim jednka to zrobię podzielę zbior danych na zbiór gdzie jest `'SalePrice'` (zmienna objaśniana) i zbiór gdzie są pozostałe zmienne.

# %%
from sklearn.model_selection import train_test_split

# %%
# dziele zbiory na zbiór gdzie jest 'SalePrice' (zmienna objaśniana) i zbiór gdzie są pozostałe zmienne
X = data_for_modeling.copy().drop('SalePrice', axis = 1)
y = data_for_modeling.SalePrice.copy()

X.head(3)
# Out:
#    MS.Zoning  Lot.Frontage  Lot.Area  Street  Alley  Land.Contour  Lot.Config  Neighborhood  Condition.1  Condition.2  Bldg.Type  House.Style  Overall.Qual  Year.Built  Year.Remod.Add  Roof.Style  Roof.Matl  Exterior.1st  Exterior.2nd  Mas.Vnr.Type  Mas.Vnr.Area  Exter.Qual  Foundation  Bsmt.Qual  Bsmt.Cond  Bsmt.Exposure  BsmtFin.Type.1  BsmtFin.SF.1  Total.Bsmt.SF  Heating  Heating.QC  Central.Air  Electrical  X1st.Flr.SF  X2nd.Flr.SF  Gr.Liv.Area  Bsmt.Full.Bath  Full.Bath  Half.Bath  Kitchen.Qual  TotRms.AbvGrd  Functional  Fireplaces  Fireplace.Qu  Garage.Type  Garage.Finish  Garage.Cars  Garage.Area  Garage.Qual  Garage.Cond  Paved.Drive  Wood.Deck.SF  Open.Porch.SF  Misc.Feature  Sale.Type  Sale.Condition
# 0  5          34            3901      1       1      3             4           18            2            2            3          2            6             2005        2006            1           0          11            13            4             182           3           2           4          3          3              5               866           1302           1        4           1            4           1302         0            1302         1               1          1          3             5              6           1           4             1            2              2            631          3            3            2            110           50             1             6          5
# 1  5          70            8400      1       1      3             0           17            2            2            0          2            4             1970        1970            1           0          8             10            3             0             2           1           3          3          1              5               804           882            1        2           1            4           882          0            882          1               1          0          2             4              6           0           0             1            3              2            525          3            3            2            240           0              1             9          4
# 2  5          60            7200      1       1      3             4           5             2            2            0          6            5             1972        2003            1           0          13            6             3             0             2           1           4          3          3              6               660           768            1        3           1            4           768          0            768          0               1          0          2             5              6           0           0             5            3              1            396          3            3            2            192           0              1             9          4

# %%
# podział data setu na zestaw treningowy i testowy za pomoca moduły train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# po podzilenieu na zestaw testowy i treningowy sprawdzę wymiary zestawów danych
print(X.shape)
print(y.shape)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1993, 56)
# (1993,)
# (1335, 56)
# (1335,)
# (658, 56)
# (658,)

# %%
# wizualizacja rozkładu zmiennej obiaśnianej w zestawie testowym i treningowym 
plt.hist(y_train, alpha=0.5)
plt.hist(y_test, alpha=0.5)
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# W kolejnym kroku zajmę się przeskalowaniem danych za pomocą modułu StandardScaler.
#
# Standaryzacja bedzie dotyczyła wszystkich zminnych. Polega na przekształceniu danych, aby ich rozkład miał średnią wartośc równą 0 i odchylenie standardowe równe 1.

# %%
# wykorzystam moduł StandardScaler z pakietu sklearn w celu przeskalowania danych
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# W celu przyśpieszenia procesu uczenia modelu można wykonać redukcję wymiarowości. W tym celu wyznaczenia optymalnej liczby komponentów wykorzystam moduł PCA (Principal Component Analysis).
#
# W pierwszym podejściu nie zastosowałem PCA przed rozpoczeciem trenowania modelu co istotnie wpłyneło na czas trenowani modelu.

# %%
from sklearn.decomposition import PCA
pca = PCA()

pca.fit(X_train_scaled)
plt.figure(figsize=(18,6))
plt.bar(range(pca.n_components_),pca.explained_variance_ratio_)
plt.show()

# %%
from sklearn.model_selection import KFold
kfold = KFold(n_splits=4, random_state=42)    # ustawiam 5 podziałów
pca = PCA(random_state=42, n_components=15)    # ustawiam 16 komponentów
scaler = StandardScaler()
print("",kfold,"\n",scaler)
# Out:
#  KFold(n_splits=4, random_state=42, shuffle=False)
#  StandardScaler()
# /Users/m.owczarek/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:297: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning

# %% [markdown]
# ***
# Przytąpie teraz to wytrenowania kilku modeli.
#
# Dla każdego z modeli wykonam pipeline danych, które stworzę za pomocą modułu `make_pipeline`. Dodatkowo w celu znalezienia najlepszych parametrów dla modelu wykorzystam moduł `GridSearchCV`.
#
# W celu oceny graficzej predykcji modelu. Dla każdego modelu przygotuję wykres rozrzutu reszt cząstowych (`Residuals Plot`), ktory pokazuje różnice między wartościami testowymi, a wartościami przewidywanymi *(reszty to różnice między wartościami obserwowanymi, a obliczonymi na podstawie wybranego modelu)*.
#
# Za pomocą tego wykresu możemy zobaczyć zakres, w jakim nasz model uchwycił zachowanie danych.  Wizualizując reszty dla serii wystąpień, możemy sprawdzić, czy są one zgodne z przypadkowym błędem. Jeśli punkty danych wydają się być równomiernie (losowo) rozproszone wokół wykreślonej linii, nasz model działa dobrze.

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import GridSearchCV
from sklearn import metrics

# %% [markdown]
# * Model Regresji Liniowej

# %%
from sklearn import linear_model

# %%
param_grid = {'polynomialfeatures__degree': [1, 2, 3, 4]}

polynomialfeatures = PolynomialFeatures()

linearregression = linear_model.LinearRegression()

pipeline = make_pipeline(scaler, 
                         pca,
                         polynomialfeatures, 
                         linearregression)

grid_lr = GridSearchCV(estimator=pipeline, 
                       param_grid=param_grid, 
                       cv=kfold, 
                       refit=True, 
                       scoring='r2')

grid_lr.fit(X_train,y_train)

print("Best parameters: ", grid_lr.best_params_)
print('----')
print("Train R2: {:.5f}".format( metrics.r2_score(y_train, grid_lr.predict(X_train))))
print("Test R2: {:.5f}".format( metrics.r2_score(y_pred = grid_lr.predict(X_test), y_true= y_test)))
# Out:
# Best parameters:  {'polynomialfeatures__degree': 2}
# ----
# Train R2: 0.92852
# Test R2: 0.90513

# %%
# Wykres rozrzutu reszt cząstkowych dla regresji liniowej

fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot()

train = ax.scatter(grid_lr.predict(X_train), grid_lr.predict(X_train)-y_train,color='blue',s=50,alpha=0.5)
test = ax.scatter(grid_lr.predict(X_test), grid_lr.predict(X_test)-y_test, s=50, color='green')

ax.hlines(y=0, xmin=0, xmax=550000, color='black')
#ax.set_title('LR')
ax.set_ylabel('Residuals')
ax.set_xlim(0,550000)  
#ax.set_ylim(-150000,150000) # nie ustawiam zakresu, ponieważ wykres sam dopasuje zakres do owartości

plt.title('Wykres rozrzutu reszt cząstkowych dla regresji liniowej')
plt.legend([train, test], ['Wartości treningowe', 'Wartości przewidywane'])


plt.show()

# %% [markdown]
# * Model Regresji ElasticNet

# %%
from sklearn.linear_model import ElasticNet

# %%
param_grid = {'polynomialfeatures__degree': [1, 2, 3, 4], 
              'elasticnet__alpha': [0.001, 0.01, 0.05, 0.1, 1, 10]}

polynomialfeatures = PolynomialFeatures()

elasticnet = ElasticNet(alpha=1, tol=0.1, random_state=42)

pipeline = make_pipeline(scaler, 
                         pca, 
                         polynomialfeatures, 
                         elasticnet)

grid_en = GridSearchCV(estimator=pipeline, 
                       param_grid=param_grid, 
                       cv=kfold, 
                       refit=True, 
                       scoring='r2')

grid_en.fit(X_train,y_train)


print("Best parameters: ", grid_en.best_params_)
print('----')
print("Train R2: {:.5f}".format( metrics.r2_score(y_train, grid_en.predict(X_train))))
print("Test R2: {:.5f}".format( metrics.r2_score(y_pred = grid_en.predict(X_test), y_true= y_test)))
# Out:
# Best parameters:  {'elasticnet__alpha': 1, 'polynomialfeatures__degree': 2}
# ----
# Train R2: 0.92337
# Test R2: 0.91039

# %%
# Wykres rozrzutu reszt cząstkowych dla regresji elasticnet

fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot()

train = ax.scatter(grid_en.predict(X_train), grid_en.predict(X_train)-y_train,color='blue',s=50,alpha=0.5)
test = ax.scatter(grid_en.predict(X_test), grid_en.predict(X_test)-y_test, s=50, color='green')

ax.hlines(y=0, xmin=0, xmax=550000, color='black')
ax.set_ylabel('Residuals')
ax.set_xlim(0,550000)  
#ax.set_ylim(-150000,150000) # nie ustawiam zakresu, ponieważ wykres sam dopasuje zakres do owartości

plt.title('Wykres rozrzutu reszt cząstkowych dla regresji elasticnet')
plt.legend([train, test], ['Wartości treningowe', 'Wartości przewidywane'])

plt.show()

# %% [markdown]
# * Model Regresji Ridge (regresji grzbietowej)

# %%
from sklearn.linear_model import Ridge

# %%
param_grid = {'polynomialfeatures__degree': [1, 2, 3, 4], 
             'ridge__alpha': [1, 10, 50, 100, 500, 1000]}

polynomialfeatures = PolynomialFeatures()

ridge = Ridge(alpha=1,  tol=0.1, random_state=42)

pipeline = make_pipeline(scaler, 
                         pca, 
                         polynomialfeatures, 
                         ridge)

grid_rdg = GridSearchCV(estimator=pipeline, 
                        param_grid=param_grid, 
                        cv=kfold, 
                        refit=True, 
                        scoring='r2')

grid_rdg.fit(X_train,y_train)

print("Best parameters: ", grid_rdg.best_params_)
print('----')
print("Train R2: {:.5f}".format( metrics.r2_score(y_train, grid_rdg.predict(X_train))))
print("Test R2: {:.5f}".format( metrics.r2_score(y_pred = grid_rdg.predict(X_test), y_true= y_test)))
# Out:
# Best parameters:  {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}
# ----
# Train R2: 0.92818
# Test R2: 0.90736

# %%
# Wykres rozrzutu reszt cząstkowych dla regresji ridge

fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot()

train = ax.scatter(grid_rdg.predict(X_train), grid_rdg.predict(X_train)-y_train,color='blue',s=50,alpha=0.5)
test = ax.scatter(grid_rdg.predict(X_test), grid_rdg.predict(X_test)-y_test, s=50, color='green')

ax.hlines(y=0, xmin=0, xmax=550000, color='black')
ax.set_ylabel('Residuals')
ax.set_xlim(0,550000)  
#ax.set_ylim(-150000,150000) # nie ustawiam zakresu, ponieważ wykres sam dopasuje zakres do owartości

plt.title('Wykres rozrzutu reszt cząstkowych dla regresji ridge')
plt.legend([train, test], ['Wartości treningowe', 'Wartości przewidywane'])

plt.show()

# %% [markdown]
# * Model Regresji Lasso

# %%
from sklearn.linear_model import Lasso

# %%
param_grid={'polynomialfeatures__degree': [1, 2, 3, 4],
                      'lasso__alpha': [1., 2., 3.]},

polynomialfeatures = PolynomialFeatures()

lasso = Lasso(alpha=1, tol=0.1)

pipeline = make_pipeline(scaler, 
                         pca, 
                         polynomialfeatures, 
                         lasso)

grid_lasso = GridSearchCV(estimator=pipeline,
                          param_grid=param_grid,
                          cv=kfold,
                          refit=True,
                          scoring='r2')

grid_lasso.fit(X_train,y_train)


print("Best parameters: ", grid_lasso.best_params_)
print('----')
print("Train R2: {:.5f}".format( metrics.r2_score(y_train, grid_lasso.predict(X_train))))
print("Test R2: {:.5f}".format( metrics.r2_score(y_pred = grid_lasso.predict(X_test), y_true= y_test)))
# Out:
# Best parameters:  {'lasso__alpha': 3.0, 'polynomialfeatures__degree': 2}
# ----
# Train R2: 0.92233
# Test R2: 0.90654

# %%
# Wykres rozrzutu reszt cząstkowych dla regresji lasso

fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot()

train = ax.scatter(grid_lasso.predict(X_train), grid_lasso.predict(X_train)-y_train,color='blue',s=50,alpha=0.5)
test = ax.scatter(grid_lasso.predict(X_test), grid_lasso.predict(X_test)-y_test, s=50, color='green')

ax.hlines(y=0, xmin=0, xmax=550000, color='black')
ax.set_ylabel('Residuals')
ax.set_xlim(0,550000)  
#ax.set_ylim(-150000,150000) # nie ustawiam zakresu, ponieważ wykres sam dopasuje zakres do owartości

plt.title('Wykres rozrzutu reszt cząstkowych dla regresji lasso')
plt.legend([train, test], ['Wartości treningowe', 'Wartości przewidywane'])

plt.show()

# %% [markdown]
# * Model Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
param_grid = {'randomforestregressor__n_estimators': [250, 500, 750, 1000], 
              'randomforestregressor__max_features': ['auto', 'sqrt', 'log2'],}

rfr = RandomForestRegressor(n_jobs=-1,
                            oob_score = True,
                            random_state=42) 

pipeline = make_pipeline(scaler, 
                         pca, 
                         rfr)

grid_rf = GridSearchCV(estimator=pipeline, 
                       param_grid=param_grid, 
                       cv=kfold, refit=True, 
                       scoring='r2')

grid_rf.fit(X_train,y_train)


print("Best parameters: ", grid_rf.best_params_)
print('----')
print("Train R2: {:.5f}".format( metrics.r2_score(y_train, grid_rf.predict(X_train))))
print("Test R2: {:.5f}".format( metrics.r2_score(y_pred = grid_rf.predict(X_test), y_true= y_test)))
# Out:
# Best parameters:  {'randomforestregressor__max_features': 'auto', 'randomforestregressor__n_estimators': 1000}
# ----
# Train R2: 0.98181
# Test R2: 0.89576

# %%
# Wykres rozrzutu reszt cząstkowych dla modelu random forest

fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot()

train = ax.scatter(grid_rf.predict(X_train), grid_rf.predict(X_train)-y_train,color='blue',s=50,alpha=0.5)
test = ax.scatter(grid_rf.predict(X_test), grid_rf.predict(X_test)-y_test, s=50, color='green')

ax.hlines(y=0, xmin=0, xmax=550000, color='black')
ax.set_ylabel('Residuals')
ax.set_xlim(0,550000)  
#ax.set_ylim(-150000,150000) # nie ustawiam zakresu, ponieważ wykres sam dopasuje zakres do owartości

plt.title('Wykres rozrzutu reszt cząstkowych dla modelu random forest')
plt.legend([train, test], ['Wartości treningowe', 'Wartości przewidywane'])

plt.show()

# %% [markdown]
# * Model Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
param_grid = {'gradientboostingregressor__n_estimators': [250, 500, 750, 1000], 
              'gradientboostingregressor__max_features': ['auto', 'sqrt', 'log2']}

gbr = GradientBoostingRegressor(n_estimators=600,
                                max_depth=5,
                                learning_rate=0.01,
                                min_samples_split=3) 

pipeline = make_pipeline(scaler, 
                         pca, 
                         gbr)

grid_gbr = GridSearchCV(estimator=pipeline, 
                       param_grid=param_grid, 
                       cv=kfold, refit=True, 
                       scoring='r2')

grid_gbr.fit(X_train,y_train)


print("Best parameters: ", grid_gbr.best_params_)
print('----')
print("Train R2: {:.5f}".format( metrics.r2_score(y_train, grid_gbr.predict(X_train))))
print("Test R2: {:.5f}".format( metrics.r2_score(y_pred = grid_gbr.predict(X_test), y_true= y_test)))
# Out:
# Best parameters:  {'gradientboostingregressor__max_features': 'auto', 'gradientboostingregressor__n_estimators': 750}
# ----
# Train R2: 0.97971
# Test R2: 0.89525

# %%
# Wykres rozrzutu reszt cząstkowych dla modelu gradient boosting

fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot()

train = ax.scatter(grid_gbr.predict(X_train), grid_gbr.predict(X_train)-y_train,color='blue',s=50,alpha=0.5)
test = ax.scatter(grid_gbr.predict(X_test), grid_gbr.predict(X_test)-y_test, s=50, color='green')

ax.hlines(y=0, xmin=0, xmax=550000, color='black')
ax.set_ylabel('Residuals')
ax.set_xlim(0,550000)  
#ax.set_ylim(-150000,150000) # nie ustawiam zakresu, ponieważ wykres sam dopasuje zakres do owartości

plt.title('Wykres rozrzutu reszt cząstkowych dla modelu gradient boosting')
plt.legend([train, test], ['Wartości treningowe', 'Wartości przewidywane'])

plt.show()

# %% [markdown]
# **Metryki**
#
# Pakiet scikit-learn posiada dużą ilość miar, które możemy wykorzystać do analizy wyników uzyskanych przez model.
# <br>https://scikit-learn.org/stable/modules/model_evaluation.html

# %%
modele = []
modele.append(('LinearRegression', grid_lr.best_estimator_))
modele.append(('ElasticNet', grid_en.best_estimator_))
modele.append(('Ridge', grid_rdg.best_estimator_))
modele.append(('Lasso', grid_lasso.best_estimator_))
modele.append(('RandomForestRegressor', grid_rf.best_estimator_))
modele.append(('GradientBoostingRegressor', grid_gbr.best_estimator_))

# %%
from sklearn import  metrics 
from sklearn.metrics import r2_score

r2_train = []
r2_test = []
explained_variance_score = []
median_absolute_error = []
mean_squared_error = []
mean_absolute_error = []

for name, model in modele:
    print('---')
    print(name)
    print("R^2 (train): {}".format(metrics.r2_score(y_train, model.predict(X_train)) ))
    print("R^2 (test): {}".format(metrics.r2_score(y_test, model.predict(X_test)) ))
    print("Explained variance score: {}".format( metrics.explained_variance_score(y_test, model.predict(X_test)) ))
    print("Median absolute error: {}".format( metrics.median_absolute_error(y_test, model.predict(X_test)) ))
    print("Mean squared error: {}".format( metrics.mean_squared_error(y_test, model.predict(X_test)) ))
    print("Mean absolute errors: {}".format(metrics.mean_absolute_error(y_test, model.predict(X_test)) ))
   
    r2_train.append(metrics.r2_score(y_train, model.predict(X_train)))
    r2_test.append(metrics.r2_score(y_test, model.predict(X_test)))
    explained_variance_score.append(metrics.explained_variance_score(y_test, model.predict(X_test)))
    median_absolute_error.append( metrics.median_absolute_error(y_test, model.predict(X_test)))
    mean_squared_error.append(metrics.mean_squared_error(y_test, model.predict(X_test)))
    mean_absolute_error.append(metrics.mean_absolute_error(y_test, model.predict(X_test)))
# Out:
# ---
# LinearRegression
# R^2 (train): 0.9285193119575053
# R^2 (test): 0.905134171469406
# Explained variance score: 0.9052395677664554
# Median absolute error: 12060.11917163535
# Mean squared error: 517912007.91902965
# Mean absolute errors: 16587.711568794315
# ---
# ElasticNet
# R^2 (train): 0.9233709732869121
# R^2 (test): 0.9103899757593583
# Explained variance score: 0.9104850628867707
# Median absolute error: 11360.616728522218
# Mean squared error: 489218386.67309517
# Mean absolute errors: 15946.582778225104
# ---
# Ridge
# R^2 (train): 0.9281844599052312
# R^2 (test): 0.9073559682846765
# Explained variance score: 0.9074573894870719
# Median absolute error: 11696.827638242714
# Mean squared error: 505782295.1698944
# Mean absolute errors: 16326.163093459309
# ---
# Lasso
# R^2 (train): 0.9223282978667867
# R^2 (test): 0.9065418064320645
# Explained variance score: 0.9066585663467818
# Median absolute error: 12641.145504437358
# Mean squared error: 510227143.2926444
# Mean absolute errors: 16514.093664718122
# ---
# RandomForestRegressor
# R^2 (train): 0.9818092072573741
# R^2 (test): 0.8957622959539576
# Explained variance score: 0.8958006785136485
# Median absolute error: 11988.131500000003
# Mean squared error: 569076973.6538486
# Mean absolute errors: 17002.896996960484
# ---
# GradientBoostingRegressor
# R^2 (train): 0.9797144593050451
# R^2 (test): 0.8952508170378296
# Explained variance score: 0.8952924306334464
# Median absolute error: 12051.90765596983
# Mean squared error: 571869349.7555833
# Mean absolute errors: 16853.56131865782

# %%
wyniki = pd.DataFrame(data=modele)

wyniki.rename({0 : 'Name', 1 : 'Model'}, axis = 1, inplace=True)
wyniki.drop(labels=['Model'], axis=1, inplace=True)
wyniki.set_index('Name', inplace=True)

wyniki['R2 (train)'] = r2_train
wyniki['R2 (test)'] = r2_test
wyniki['(EVS)  Explained variance score (test)'] = explained_variance_score
wyniki['(MedAE)  Median absolute error (test)'] = median_absolute_error
wyniki['(MSE)  Mean squared error (test)'] = mean_squared_error
wyniki['(MAE)  Mean absolute errors (test)'] = mean_absolute_error
wyniki
# Out:
#                            R2 (train)  R2 (test)  (EVS)  Explained variance score (test)  (MedAE)  Median absolute error (test)  (MSE)  Mean squared error (test)  (MAE)  Mean absolute errors (test)
# Name
# LinearRegression           0.928519    0.905134   0.905240                                12060.119172                           5.179120e+08                      16587.711569
# ElasticNet                 0.923371    0.910390   0.910485                                11360.616729                           4.892184e+08                      15946.582778
# Ridge                      0.928184    0.907356   0.907457                                11696.827638                           5.057823e+08                      16326.163093
# Lasso                      0.922328    0.906542   0.906659                                12641.145504                           5.102271e+08                      16514.093665
# RandomForestRegressor      0.981809    0.895762   0.895801                                11988.131500                           5.690770e+08                      17002.896997
# GradientBoostingRegressor  0.979714    0.895251   0.895292                                12051.907656                           5.718693e+08                      16853.561319

# %% [markdown]
# ## **6. Podsumowanie wyników i projektu**
#
# * Podsumowanie wyników
#
#
# Finalnie najlepsze wyniki osiągnął model `ElasticNet` *Wskaźnik **R2** oznacza jak dobrzez przyszłe wartości będą przewidywane przez model*.
# Na zbiorze testowym najlepsze wyniki osiagnął model `RandomForest` i `GradientBoosting`. Być może wynika to z overfitingu modelu.
#
# Różnice są nie wielkie, na tyle, że przy innym podziale zestawu danych na zestaw treningowy i testowy wyniki mogłyby się zmienić.
#
# Także wartość **MAE** pokazuję, że model ElasticNet mylił sie najmniej *wskaźnik **MAE** oznacza dystans pomiędzy przewidywanymi, a aktualnymi wartościami*
#
# Otrzymane wyniki potwierdzaja także wykonane wizulizacje.

# %% [markdown]
# **Wnioski i przemyślenia**:
#
# - Realizacja projektu pozwoliła na ustrukturyzowanie wiedzy i pozwoliła na praktyczne przetestowanie i wykorzytanie konceptów, które omawiliśmy podczas bootcampu.
#
# - Jednym z największych wyzwań było dla mnie ustalenie odpowiedniego flow dla całago projektu tj. jakie działania wykonać w pierwszej kolejności, jak dane działania będą wpływały na kolejne kroki (zarówno na etapie czyszczenia i anlizay danych jak i na etapie modelowania).
#
# - Odpowiednie zrozumienie danych jest kluczowe dla projektu. W data secie były niespojności na pozimie słowników np.: wystęowały wartości słownikowe NA oraz None, które po odpowednim połączeniu z innymi zmiennymi można zamienić.
#
# - Istotne okazało się zamienienie zmiennych porządkowych na zmienne numeryczne, ponieważ wpłyneło to na korelacje między zmienna objaśnianą, a pozostałymi zmiennymi (tj.: zmienne porządkowe miały istotny wpływ na zmienną objaśnianą).
#
# - W pierwszej wersji projektu wykorzystałem także bibliotekę Pandas Profiling Report, która pozwala na kompleksową eksloracyjną analizę danych. Wynik tej analizy jest dostępny z poziomu jupyter notebook'a w iframe przez co jest możliwośc jego oglądania tylko kiedy nootbook działa. Jest możliowść zrzuucenia wyniku anlizy do raportu w formacie .html, ale ten plik miał ponad 45MB. Finalnie zrezygnowałem z wykorzystania tej biblioteki, ponieważ wszystkie anlizy wykonałem samodzielnie, ale z pewnościa jest to interesujące narzędzie.
#
# - Bardzo wiele informacji i lepsze zrozumienie danych dało mi zweryfikowanie korelacji między zmiennymi, warto wcześniej wykonać analize korelacji
#
# **Co mogłem zrobić lepiej?**
#
# - Wykonałem kilka wizualizacji, być może mogłem więcej czasu poświęcić na ten etpa i zastoswać bardziej zaawansowane sposoby wizualizacji.
#
# - Na etapie czyszczenia danych zaminiłem zmienną rok budowy garażu na wiek co lepiej oddaje watość tej zminnej, być może więcej podobnych przekształceń można było wykonać.
#
# - W pierwszym podejściu do zamiany danych kategorycznych na numeryczne (przed etapem modelowania) wykorzystałem metodę z biblioteki Pandas `get.dummies` jednak znalazłem informacje na stackoverflow, że inne metody moga być lepsze. Chciałem wykorzystać `OneHotEncoder`, ale pojawiały się błędy i wykorzystałem `LabelEncoder`. Być może warto byłoby zastosować tą metodę wcześniej np.: tuż po zamianie zmiennych porządkowych na numeryczne co mogłoby włynąć na korelacje danych.
#
# - W pierwszym podejściu nie wykonałem redukcji wymiarowwości co spowodowało, że moje modele trenowały się bardzo długo (nie dotrwałem do końca:). Po wykorzystaniu modułu `PCA` trenowanie modeli było znacznie szybsze, ale nie jestem pewien czy dobrałem najlepszy wskaźnik ilości komponentów (wybrałem wskaźnik na podstawie wizualizacji i metodą "prób i błędów". Ten etap na pewno można optymalizować.
#
# - w celu poprawy wyników mogłem wykonać walidację krzyżową, która ogranicza ryzyko wystapienia overfitingu. Jednak mój komputer nie mógł przeliczyć tego wyniku (w szczególności dla modelu Random Forest i gradient Bosting

# %% [markdown]
# ***

# %% [markdown]
# **Przydatne linki i literatura**
# <br>https://jakevdp.github.io/PythonDataScienceHandbook/
# <br>https://pandas.pydata.org/pandas-docs/stable/index.html
# <br>https://towardsdatascience.com/exploratory-data-analysis-eda-python-87178e35b14
# <br>https://machinelearningmastery.com/one-hot-encoding-for-categorical-data/
# <br>https://scikit-learn.org/stable/
# <br>https://pandas-profiling.github.io/pandas-profiling/docs/master/rtd/
# <br>https://scikit-learn.org/stable/modules/generated/sklearn.metrics.r2_score.html#sklearn.metrics.r2_score
# <br>https://towardsdatascience.com/pca-using-python-scikit-learn-e653f8989e60
# <br>https://www.districtdatalabs.com/visual-diagnostics-for-more-informed-machine-learning-part-3
